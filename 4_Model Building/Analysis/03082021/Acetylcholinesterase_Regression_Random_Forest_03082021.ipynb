# %% [markdown]
# Bioinformatics Project - Computational Drug Discovery [Part 4] Regression Models with Random Forest
# Chanin Nantasenamat
#
# 'Data Professor' YouTube channel
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 4, we will be building a regression model of acetylcholinesterase inhibitors using the random forest algorithm.

# %% [markdown]
# **1. Import Libraries**

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# **2.Load the data set**

# %%
! wget https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/3_Dataset%20Preparation/output/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp_03082021.csv
# Out:
# --2021-08-03 03:05:30--  https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/3_Dataset%20Preparation/output/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp_03082021.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9089397 (8.7M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp_03082021.csv’
#
# acetylcholinesteras 100%[===================>]   8.67M  --.-KB/s    in 0.05s
#
# 2021-08-03 03:05:30 (162 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp_03082021.csv’ saved [9089397/9089397]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp_03082021.csv')

# %%
df
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.124939
# 1              1           1           1  ...             0             0  7.000000
# 2              1           1           1  ...             0             0  4.301030
# 3              1           1           0  ...             0             0  6.522879
# 4              1           1           0  ...             0             0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 5098           1           1           1  ...             0             0  3.575118
# 5099           1           1           1  ...             0             0  6.130768
# 5100           1           1           1  ...             0             0  6.292430
# 5101           1           1           1  ...             0             0  3.903090
# 5102           1           1           1  ...             0             0  4.000000
#
# [5103 rows x 882 columns]

# %% [markdown]
# **3.Input features**
#
# The Acetylcholinesterase data set contains 881 input features and 1 output variable (pIC50 values).

# %% [markdown]
# 3.1 Input features

# %%
x = df.drop('pIC50', axis =1)
x
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 5098           1           1  ...             0             0
# 5099           1           1  ...             0             0
# 5100           1           1  ...             0             0
# 5101           1           1  ...             0             0
# 5102           1           1  ...             0             0
#
# [5103 rows x 881 columns]

# %% [markdown]
# 3.2. Output features

# %%
y = df.pIC50
y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 5098    3.575118
# 5099    6.130768
# 5100    6.292430
# 5101    3.903090
# 5102    4.000000
# Name: pIC50, Length: 5103, dtype: float64

# %% [markdown]
# 3.3. Let's examine the data dimension

# %%
x.shape
# Out:
# (5103, 881)

# %%
y.shape
# Out:
# (5103,)

# %% [markdown]
# 3.4. Remove low variance features

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(0.8*(1-0.8)))
x = selection.fit_transform(x)

# %%
x.shape
# Out:
# (5103, 140)

# %% [markdown]
# 4. Data split (80/20 ratio)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
x_train.shape, y_train.shape
# Out:
# ((4082, 140), (4082,))

# %%
x_test.shape, y_test.shape
# Out:
# ((1021, 140), (1021,))

# %% [markdown]
# Building a linear regression model using Random Forest

# %%
import numpy as np
np.random.seed(100)
model = RandomForestRegressor(n_estimators=100)
model.fit(x_train,y_train)
r2=model.score(x_test,y_test)
r2
# Out:
# 0.515840988661282

# %%
y_pred=model.predict(x_test)
