# %% [markdown]
# # **Computational Drug Discovery Pipelines-**
# ## **Data Collection and Pre-processing**

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.7-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.5 MB/s
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.2-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.5 MB/s
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting pyyaml>=5.4
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 14.5 MB/s
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, pyyaml, itsdangerous, requests-cache, chembl-webresource-client
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.0.1 which is incompatible.
# Successfully installed chembl-webresource-client-0.10.7 itsdangerous-2.0.1 pyyaml-5.4.1 requests-cache-0.7.2 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ...  tax_id
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...  ...    9606
# 1                                                  []  ...    9606
# 2                                                  []  ...    7227
# 3   [{'xref_id': 'P04058', 'xref_name': None, 'xre...  ...    7787
# 4   [{'xref_id': 'P21836', 'xref_name': None, 'xre...  ...   10090
# 5   [{'xref_id': 'P37136', 'xref_name': None, 'xre...  ...   10116
# 6   [{'xref_id': 'O42275', 'xref_name': None, 'xre...  ...    8005
# 7   [{'xref_id': 'P23795', 'xref_name': None, 'xre...  ...    9913
# 8                                                  []  ...    7165
# 9                                                  []  ...    7038
# 10                                                 []  ...    7539
# 11                                                 []  ...   94400
# 12                                                 []  ...    9031
# 13                                                 []  ...    7955
# 14                                                 []  ...    7159
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...  ...    7370
# 16                                                 []  ...   51655
# 17                                                 []  ...    7370
# 18                                                 []  ...  121226
# 19                                                 []  ...   69820
# 20                                                 []  ...  195883
# 21                                                 []  ...   13262
# 22                                                 []  ...    6239
# 23                                                 []  ...   10116
#
# [24 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for Human Acetylcholinesterase (first entry)**

# %% [markdown]
# We will assign the fourth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# Here, we will retrieve only bioactivity data for Human Acetylcholinesterase (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id  ... upper_value value
# 0             None        33969  ...        None  0.75
# 1             None        37563  ...        None   0.1
# 2             None        37565  ...        None  50.0
#
# [3 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('AChE_bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we save the file in the **data** folder in our colab notebooks folder

# %%
#! mkdir "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/data"

# %%
! cp AChE_bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/Data Collection and Pre-processing/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/Data Collection and Pre-processing/data"
# Out:
# total 3859
# -rw------- 1 root root 3870914 Aug  2 09:35 AChE_bioactivity_data.csv
# -rw------- 1 root root   70334 Aug  2 02:17 bioactivity_data.csv
# -rw------- 1 root root    9337 Aug  2 02:38 bioactivity_preprocessed_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# AChE_bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head AChE_bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,33969,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '19.61', 'le': '0.36', 'lle': '3.32', 'sei': '9.21'}",CHEMBL133897,,CHEMBL133897,6.12,False,http://www.openphacts.org/units/Nanomolar,252547,=,1,True,=,,IC50,nM,,750.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.75
# ,37563,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '18.57', 'le': '0.38', 'lle': '2.45', 'sei': '13.72'}",CHEMBL336398,,CHEMBL336398,7.00,False,http://www.openphacts.org/units/Nanomolar,252533,=,1,True,=,,IC50,nM,,100.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.1
# ,37565,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1,,,CHEMBL1148382,J. Med. Chem.,2004.0,,CHEMBL131588,,CHEMBL131588,,False,http://www.openphacts.org/units/Nanomolar,252530,>,1,True,>,,IC50,nM,,50000.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,50.0
# ,38902,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '16.11', 'le': '0.34', 'lle': '1.81', 'sei': '12.78'}",CHEMBL130628,,CHEMBL130628,6.52,False,http://www.openphacts.org/units/Nanomolar,252534,=,1,True,=,,IC50,nM,,300.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.3
# ,41170,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '17.60', 'le': '0.36', 'lle': '3.00', 'sei': '10.12'}",CHEMBL130478,,CHEMBL130478,6.10,False,http://www.openphacts.org/units/Nanomolar,252552,=,1,True,=,,IC50,nM,,800.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.8
# ,42363,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)c1ccccc1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '16.60', 'le': '0.32', 'lle': '1.54', 'sei': '11.01'}",CHEMBL130112,,CHEMBL130112,5.62,False,http://www.openphacts.org/units/Nanomolar,252551,=,1,True,=,,IC50,nM,,2400.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,2.4
# ,43561,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)C,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '23.59', 'le': '0.50', 'lle': '4.15', 'sei': '13.72'}",CHEMBL130098,,CHEMBL130098,7.00,False,http://www.openphacts.org/units/Nanomolar,252525,=,1,True,=,,IC50,nM,,100.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.1
# ,44825,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CCCCCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCOCC1,,,CHEMBL1148382,J. Med. Chem.,2004.0,,CHEMBL337486,,CHEMBL337486,,False,http://www.openphacts.org/units/Nanomolar,252538,>,1,True,>,,IC50,nM,,50000.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,50.0
# ,45908,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '20.85', 'le': '0.42', 'lle': '3.89', 'sei': '10.12'}",CHEMBL336538,,CHEMBL336538,6.10,False,http://www.openphacts.org/units/Nanomolar,252527,=,1,True,=,,IC50,nM,,800.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.8

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
# 7548             None     20708930  ...        None    0.1
#
# [6342 rows x 45 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
df2.molecule_chembl_id
# Out:
# 0        CHEMBL133897
# 1        CHEMBL336398
# 2        CHEMBL131588
# 3        CHEMBL130628
# 4        CHEMBL130478
#             ...
# 7544    CHEMBL4645659
# 7545     CHEMBL513063
# 7546    CHEMBL4640608
# 7547    CHEMBL4173961
# 7548         CHEMBL95
# Name: molecule_chembl_id, Length: 6342, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL133897',
#  'CHEMBL336398',
#  'CHEMBL131588',
#  'CHEMBL130628',
#  'CHEMBL130478',
#  'CHEMBL130112',
#  'CHEMBL130098',
#  'CHEMBL337486',
#  'CHEMBL336538',
#  'CHEMBL131051',
#  'CHEMBL341437',
#  'CHEMBL335033',
#  'CHEMBL122983',
#  'CHEMBL338720',
#  'CHEMBL339995',
#  'CHEMBL335158',
#  'CHEMBL131536',
#  'CHEMBL106126',
#  'CHEMBL334971',
#  'CHEMBL336625',
#  'CHEMBL130666',
#  'CHEMBL134061',
#  'CHEMBL133388',
#  'CHEMBL130645',
#  'CHEMBL133580',
#  'CHEMBL336524',
#  'CHEMBL336276',
#  'CHEMBL334395',
#  'CHEMBL131320',
#  'CHEMBL339297',
#  'CHEMBL337714',
#  'CHEMBL122575',
#  'CHEMBL130704',
#  'CHEMBL46151',
#  'CHEMBL54126',
#  'CHEMBL297316',
#  'CHEMBL65667',
#  'CHEMBL431519',
#  'CHEMBL296429',
#  'CHEMBL154972',
#  'CHEMBL152722',
#  'CHEMBL544022',
#  'CHEMBL349127',
#  'CHEMBL156659',
#  'CHEMBL45118',
#  'CHEMBL542609',
#  'CHEMBL155322',
#  'CHEMBL154211',
#  'CHEMBL1203537',
#  'CHEMBL86',
#  'CHEMBL47375',
#  'CHEMBL542360',
#  'CHEMBL345849',
#  'CHEMBL154689',
#  'CHEMBL346733',
#  'CHEMBL416464',
#  'CHEMBL1203539',
#  'CHEMBL347729',
#  'CHEMBL296786',
#  'CHEMBL63173',
#  'CHEMBL433041',
#  'CHEMBL292788',
#  'CHEMBL33051',
#  'CHEMBL155392',
#  'CHEMBL153311',
#  'CHEMBL543546',
#  'CHEMBL1420',
#  'CHEMBL556172',
#  'CHEMBL154263',
#  'CHEMBL544669',
#  'CHEMBL62664',
#  'CHEMBL155111',
#  'CHEMBL1203534',
#  'CHEMBL541044',
#  'CHEMBL543779',
#  'CHEMBL155495',
#  'CHEMBL64011',
#  'CHEMBL65585',
#  'CHEMBL347539',
#  'CHEMBL154433',
#  'CHEMBL157208',
#  'CHEMBL1790041',
#  'CHEMBL65356',
#  'CHEMBL154366',
#  'CHEMBL153821',
#  'CHEMBL416644',
#  'CHEMBL94',
#  'CHEMBL303574',
#  'CHEMBL65018',
#  'CHEMBL296277',
#  'CHEMBL66309',
#  'CHEMBL1203535',
#  'CHEMBL296560',
#  'CHEMBL152260',
#  'CHEMBL154950',
#  'CHEMBL296669',
#  'CHEMBL1203538',
#  'CHEMBL19060',
#  'CHEMBL422977',
#  'CHEMBL11805',
#  'CHEMBL302179',
#  'CHEMBL94',
#  'CHEMBL27673',
#  'CHEMBL132377',
#  'CHEMBL132133',
#  'CHEMBL95',
#  'CHEMBL134488',
#  'CHEMBL134382',
#  'CHEMBL59109',
#  'CHEMBL286990',
#  'CHEMBL294891',
#  'CHEMBL1255901',
#  'CHEMBL95',
#  'CHEMBL89011',
#  'CHEMBL748',
#  'CHEMBL50608',
#  'CHEMBL29300',
#  'CHEMBL27675',
#  'CHEMBL435373',
#  'CHEMBL60167',
#  'CHEMBL89012',
#  'CHEMBL314800',
#  'CHEMBL553212',
#  'CHEMBL156630',
#  'CHEMBL315013',
#  'CHEMBL155754',
#  'CHEMBL314658',
#  'CHEMBL87170',
#  'CHEMBL87959',
#  'CHEMBL87295',
#  'CHEMBL82810',
#  'CHEMBL157182',
#  'CHEMBL88049',
#  'CHEMBL87128',
#  'CHEMBL160219',
#  'CHEMBL445916',
#  'CHEMBL85473',
#  'CHEMBL314502',
#  'CHEMBL87320',
#  'CHEMBL87280',
#  'CHEMBL348607',
#  'CHEMBL313809',
#  'CHEMBL87849',
#  'CHEMBL314398',
#  'CHEMBL87373',
#  'CHEMBL156931',
#  'CHEMBL83005',
#  'CHEMBL315515',
#  'CHEMBL441632',
#  'CHEMBL87937',
#  'CHEMBL441808',
#  'CHEMBL87649',
#  'CHEMBL160836',
#  'CHEMBL156861',
#  'CHEMBL314766',
#  'CHEMBL315013',
#  'CHEMBL88026',
#  'CHEMBL86233',
#  'CHEMBL155350',
#  'CHEMBL433041',
#  'CHEMBL155863',
#  'CHEMBL87980',
#  'CHEMBL87441',
#  'CHEMBL315013',
#  'CHEMBL158946',
#  'CHEMBL315013',
#  'CHEMBL87550',
#  'CHEMBL609440',
#  'CHEMBL350464',
#  'CHEMBL313271',
#  'CHEMBL423313',
#  'CHEMBL309667',
#  'CHEMBL419470',
#  'CHEMBL80221',
#  'CHEMBL94',
#  'CHEMBL431844',
#  'CHEMBL80247',
#  'CHEMBL418917',
#  'CHEMBL77896',
#  'CHEMBL369661',
#  'CHEMBL94',
#  'CHEMBL502',
#  'CHEMBL74089',
#  'CHEMBL134057',
#  'CHEMBL76640',
#  'CHEMBL76241',
#  'CHEMBL431784',
#  'CHEMBL51934',
#  'CHEMBL352500',
#  'CHEMBL292314',
#  'CHEMBL355740',
#  'CHEMBL54727',
#  'CHEMBL75919',
#  'CHEMBL95',
#  'CHEMBL309351',
#  'CHEMBL75743',
#  'CHEMBL76135',
#  'CHEMBL440497',
#  'CHEMBL368196',
#  'CHEMBL62084',
#  'CHEMBL172118',
#  'CHEMBL1202875',
#  'CHEMBL95',
#  'CHEMBL62084',
#  'CHEMBL134057',
#  'CHEMBL436367',
#  'CHEMBL132365',
#  'CHEMBL3215535',
#  'CHEMBL1202865',
#  'CHEMBL133520',
#  'CHEMBL130373',
#  'CHEMBL95',
#  'CHEMBL1202884',
#  'CHEMBL263198',
#  'CHEMBL133906',
#  'CHEMBL1204162',
#  'CHEMBL134240',
#  'CHEMBL132030',
#  'CHEMBL133448',
#  'CHEMBL130880',
#  'CHEMBL1202874',
#  'CHEMBL133441',
#  'CHEMBL130427',
#  'CHEMBL134154',
#  'CHEMBL132260',
#  'CHEMBL1204299',
#  'CHEMBL1204296',
#  'CHEMBL1202885',
#  'CHEMBL502',
#  'CHEMBL337453',
#  'CHEMBL335922',
#  'CHEMBL132619',
#  'CHEMBL293316',
#  'CHEMBL61515',
#  'CHEMBL54126',
#  'CHEMBL442361',
#  'CHEMBL58034',
#  'CHEMBL61965',
#  'CHEMBL59790',
#  'CHEMBL62210',
#  'CHEMBL57003',
#  'CHEMBL291783',
#  'CHEMBL294498',
#  'CHEMBL300170',
#  'CHEMBL61312',
#  'CHEMBL293268',
#  'CHEMBL293751',
#  'CHEMBL59192',
#  'CHEMBL300176',
#  'CHEMBL61905',
#  'CHEMBL58511',
#  'CHEMBL59074',
#  'CHEMBL294674',
#  'CHEMBL57842',
#  'CHEMBL299898',
#  'CHEMBL60596',
#  'CHEMBL62031',
#  'CHEMBL60074',
#  'CHEMBL59490',
#  'CHEMBL61180',
#  'CHEMBL60180',
#  'CHEMBL294152',
#  'CHEMBL305386',
#  'CHEMBL294897',
#  'CHEMBL58190',
#  'CHEMBL60745',
#  'CHEMBL58252',
#  'CHEMBL58194',
#  'CHEMBL61126',
#  'CHEMBL294251',
#  'CHEMBL60874',
#  'CHEMBL294292',
#  'CHEMBL299435',
#  'CHEMBL305670',
#  'CHEMBL305670',
#  'CHEMBL94',
#  'CHEMBL94',
#  'CHEMBL75729',
#  'CHEMBL75729',
#  'CHEMBL74950',
#  'CHEMBL74950',
#  'CHEMBL74107',
#  'CHEMBL74107',
#  'CHEMBL94',
#  'CHEMBL94',
#  'CHEMBL301610',
#  'CHEMBL74257',
#  'CHEMBL74257',
#  'CHEMBL307721',
#  'CHEMBL307721',
#  'CHEMBL308503',
#  'CHEMBL308503',
#  'CHEMBL308043',
#  'CHEMBL308043',
#  'CHEMBL74926',
#  'CHEMBL74926',
#  'CHEMBL340542',
#  'CHEMBL128894',
#  'CHEMBL340866',
#  'CHEMBL337002',
#  'CHEMBL422971',
#  'CHEMBL340854',
#  'CHEMBL340599',
#  'CHEMBL128292',
#  'CHEMBL348318',
#  'CHEMBL263322',
#  'CHEMBL340216',
#  'CHEMBL131286',
#  'CHEMBL131318',
#  'CHEMBL340929',
#  'CHEMBL156157',
#  'CHEMBL129684',
#  'CHEMBL502',
#  'CHEMBL155121',
#  'CHEMBL153865',
#  'CHEMBL157410',
#  'CHEMBL155945',
#  'CHEMBL158232',
#  'CHEMBL340409',
#  'CHEMBL335329',
#  'CHEMBL155768',
#  'CHEMBL130831',
#  'CHEMBL155746',
#  'CHEMBL347354',
#  'CHEMBL130738',
#  'CHEMBL158174',
#  'CHEMBL345241',
#  'CHEMBL156763',
#  'CHEMBL343237',
#  'CHEMBL345905',
#  'CHEMBL54126',
#  'CHEMBL128172',
#  'CHEMBL157017',
#  'CHEMBL155128',
#  'CHEMBL345847',
#  'CHEMBL158252',
#  'CHEMBL156874',
#  'CHEMBL95',
#  'CHEMBL341251',
#  'CHEMBL445124',
#  'CHEMBL92142',
#  'CHEMBL553187',
#  'CHEMBL130956',
#  'CHEMBL93936',
#  'CHEMBL335167',
#  'CHEMBL92629',
#  'CHEMBL130270',
#  'CHEMBL340867',
#  'CHEMBL330004',
#  'CHEMBL93123',
#  'CHEMBL420625',
#  'CHEMBL92460',
#  'CHEMBL340391',
#  'CHEMBL92955',
#  'CHEMBL502',
#  'CHEMBL131210',
#  'CHEMBL126939',
#  'CHEMBL329531',
#  'CHEMBL418955',
#  'CHEMBL94',
#  'CHEMBL94',
#  'CHEMBL92663',
#  'CHEMBL502',
#  'CHEMBL131598',
#  'CHEMBL543711',
#  'CHEMBL335962',
#  'CHEMBL131825',
#  'CHEMBL93619',
#  'CHEMBL134251',
#  'CHEMBL337675',
#  'CHEMBL94186',
#  'CHEMBL92463',
#  'CHEMBL95',
#  'CHEMBL335220',
#  'CHEMBL130363',
#  'CHEMBL92958',
#  'CHEMBL130672',
#  'CHEMBL94059',
#  'CHEMBL74926',
#  'CHEMBL132531',
#  'CHEMBL132285',
#  'CHEMBL433379',
#  'CHEMBL129837',
#  'CHEMBL328102',
#  'CHEMBL130458',
#  'CHEMBL308043',
#  'CHEMBL95',
#  'CHEMBL92775',
#  'CHEMBL92736',
#  'CHEMBL91291',
#  'CHEMBL3215535',
#  'CHEMBL94',
#  'CHEMBL413765',
#  'CHEMBL359198',
#  'CHEMBL609671',
#  'CHEMBL609672',
#  'CHEMBL612098',
#  'CHEMBL612099',
#  'CHEMBL54126',
#  'CHEMBL612100',
#  'CHEMBL539109',
#  'CHEMBL95',
#  'CHEMBL609409',
#  'CHEMBL54727',
#  'CHEMBL609149',
#  'CHEMBL60745',
#  'CHEMBL94',
#  'CHEMBL609150',
#  'CHEMBL140020',
#  'CHEMBL609668',
#  'CHEMBL542467',
#  'CHEMBL540833',
#  'CHEMBL127465',
#  'CHEMBL340427',
#  'CHEMBL544592',
#  'CHEMBL124933',
#  'CHEMBL542220',
#  'CHEMBL127857',
#  'CHEMBL557405',
#  'CHEMBL340228',
#  'CHEMBL94',
#  'CHEMBL544126',
#  'CHEMBL543655',
#  'CHEMBL124156',
#  'CHEMBL340171',
#  'CHEMBL539045',
#  'CHEMBL553803',
#  'CHEMBL544823',
#  'CHEMBL27673',
#  'CHEMBL418917',
#  'CHEMBL99581',
#  'CHEMBL174228',
#  'CHEMBL173935',
#  'CHEMBL176521',
#  'CHEMBL319541',
#  'CHEMBL79012',
#  'CHEMBL99655',
#  'CHEMBL317162',
#  'CHEMBL19060',
#  'CHEMBL143055',
#  'CHEMBL609977',
#  'CHEMBL609977',
#  'CHEMBL609977',
#  'CHEMBL609977',
#  'CHEMBL174710',
#  'CHEMBL94',
#  'CHEMBL80221',
#  'CHEMBL176773',
#  'CHEMBL174046',
#  'CHEMBL176308',
#  'CHEMBL176308',
#  'CHEMBL176308',
#  'CHEMBL176308',
#  'CHEMBL94',
#  'CHEMBL137059',
#  'CHEMBL263785',
#  'CHEMBL173607',
#  'CHEMBL95',
#  'CHEMBL368075',
#  'CHEMBL75919',
#  'CHEMBL76640',
#  'CHEMBL100366',
#  'CHEMBL173136',
#  'CHEMBL173309',
#  'CHEMBL173309',
#  'CHEMBL173309',
#  'CHEMBL173309',
#  'CHEMBL175047',
#  'CHEMBL54727',
#  'CHEMBL176585',
#  'CHEMBL99414',
#  'CHEMBL177052',
#  'CHEMBL172442',
#  'CHEMBL11805',
#  'CHEMBL173018',
#  'CHEMBL173018',
#  'CHEMBL173018',
#  'CHEMBL173018',
#  'CHEMBL431784',
#  'CHEMBL99284',
#  'CHEMBL59730',
#  'CHEMBL11805',
#  'CHEMBL59782',
#  'CHEMBL59782',
#  'CHEMBL25629',
#  'CHEMBL94546',
#  'CHEMBL293842',
#  'CHEMBL12324',
#  'CHEMBL62085',
#  'CHEMBL62085',
#  'CHEMBL61929',
#  'CHEMBL61929',
#  'CHEMBL294745',
#  'CHEMBL59977',
#  'CHEMBL59977',
#  'CHEMBL60308',
#  'CHEMBL61561',
#  'CHEMBL61561',
#  'CHEMBL11514',
#  'CHEMBL329012',
#  'CHEMBL95',
#  'CHEMBL60119',
#  'CHEMBL60119',
#  'CHEMBL61221',
#  'CHEMBL61221',
#  'CHEMBL294525',
#  'CHEMBL294525',
#  'CHEMBL274107',
#  'CHEMBL24457',
#  'CHEMBL268481',
#  'CHEMBL25524',
#  'CHEMBL292121',
#  'CHEMBL61849',
#  'CHEMBL61849',
#  'CHEMBL94',
#  'CHEMBL278342',
#  'CHEMBL62084',
#  'CHEMBL62084',
#  'CHEMBL25149',
#  'CHEMBL94217',
#  'CHEMBL64815',
#  'CHEMBL64815',
#  'CHEMBL328468',
#  'CHEMBL59844',
#  'CHEMBL302842',
#  'CHEMBL302842',
#  'CHEMBL2113719',
#  'CHEMBL329231',
#  'CHEMBL94',
#  'CHEMBL292122',
#  'CHEMBL58122',
#  'CHEMBL283509',
#  'CHEMBL24686',
#  'CHEMBL95020',
#  'CHEMBL61533',
#  'CHEMBL61533',
#  'CHEMBL60167',
#  'CHEMBL24844',
#  'CHEMBL61486',
#  'CHEMBL61486',
#  'CHEMBL292480',
#  'CHEMBL61715',
#  'CHEMBL61715',
#  'CHEMBL274107',
#  'CHEMBL11833',
#  'CHEMBL24519',
#  'CHEMBL274107',
#  'CHEMBL95',
#  'CHEMBL64615',
#  'CHEMBL61986',
#  'CHEMBL61986',
#  'CHEMBL292314',
#  'CHEMBL292314',
#  'CHEMBL61850',
#  'CHEMBL24416',
#  'CHEMBL293896',
#  'CHEMBL59628',
#  'CHEMBL59628',
#  'CHEMBL304447',
#  'CHEMBL61930',
#  'CHEMBL61930',
#  'CHEMBL418643',
#  'CHEMBL418643',
#  'CHEMBL277665',
#  'CHEMBL64465',
#  'CHEMBL64465',
#  'CHEMBL61506',
#  'CHEMBL61506',
#  'CHEMBL357551',
#  'CHEMBL94',
#  'CHEMBL502',
#  'CHEMBL153934',
#  'CHEMBL157336',
#  'CHEMBL139571',
#  'CHEMBL344656',
#  'CHEMBL332760',
#  'CHEMBL348216',
#  'CHEMBL150156',
#  'CHEMBL333580',
#  'CHEMBL146319',
#  'CHEMBL659',
#  'CHEMBL147465',
#  'CHEMBL357987',
#  'CHEMBL151507',
#  'CHEMBL338975',
#  'CHEMBL150212',
#  'CHEMBL148832',
#  'CHEMBL355986',
#  'CHEMBL356000',
#  'CHEMBL423397',
#  'CHEMBL149026',
#  'CHEMBL1255901',
#  'CHEMBL636',
#  'CHEMBL357981',
#  'CHEMBL347749',
#  'CHEMBL346399',
#  'CHEMBL124054',
#  'CHEMBL557400',
#  'CHEMBL359312',
#  'CHEMBL748',
#  'CHEMBL123248',
#  'CHEMBL556186',
#  'CHEMBL147517',
#  'CHEMBL538109',
#  'CHEMBL120279',
#  'CHEMBL538852',
#  'CHEMBL344736',
#  'CHEMBL149017',
#  'CHEMBL149542',
#  'CHEMBL123249',
#  'CHEMBL122834',
#  'CHEMBL121810',
#  'CHEMBL433041',
#  'CHEMBL149084',
#  'CHEMBL145928',
#  'CHEMBL502',
#  'CHEMBL150164',
#  'CHEMBL147025',
#  'CHEMBL123831',
#  'CHEMBL95',
#  'CHEMBL538853',
#  'CHEMBL91291',
#  'CHEMBL502',
#  'CHEMBL92460',
#  'CHEMBL93619',
#  'CHEMBL93936',
#  'CHEMBL94',
#  'CHEMBL92955',
#  'CHEMBL92958',
#  'CHEMBL433379',
#  'CHEMBL418955',
#  'CHEMBL96246',
#  'CHEMBL95',
#  'CHEMBL329531',
#  'CHEMBL330004',
#  'CHEMBL328102',
#  'CHEMBL93241',
#  'CHEMBL328715',
#  'CHEMBL92663',
#  'CHEMBL92142',
#  'CHEMBL92629',
#  'CHEMBL92463',
#  'CHEMBL420625',
#  'CHEMBL93123',
#  'CHEMBL92775',
#  'CHEMBL92736',
#  'CHEMBL94186',
#  'CHEMBL94059',
#  'CHEMBL2448609',
#  'CHEMBL34222',
#  'CHEMBL416586',
#  'CHEMBL416586',
#  'CHEMBL32964',
#  'CHEMBL288549',
#  'CHEMBL34002',
#  'CHEMBL33098',
#  'CHEMBL34222',
#  'CHEMBL284938',
#  'CHEMBL32966',
#  'CHEMBL33173',
#  'CHEMBL287691',
#  'CHEMBL32543',
#  'CHEMBL416586',
#  'CHEMBL286690',
#  'CHEMBL33727',
#  'CHEMBL32453',
#  'CHEMBL34222',
#  'CHEMBL62373',
#  'CHEMBL32543',
#  'CHEMBL33161',
#  'CHEMBL32452',
#  'CHEMBL33642',
#  'CHEMBL433041',
#  'CHEMBL284369',
#  'CHEMBL284519',
#  'CHEMBL32653',
#  'CHEMBL94',
#  'CHEMBL95',
#  'CHEMBL95',
#  'CHEMBL51934',
#  'CHEMBL51934',
#  'CHEMBL1127',
#  'CHEMBL1127',
#  'CHEMBL318026',
#  'CHEMBL318026',
#  'CHEMBL319451',
#  'CHEMBL319451',
#  'CHEMBL324975',
#  'CHEMBL325505',
#  'CHEMBL27673',
#  'CHEMBL326308',
#  'CHEMBL327100',
#  'CHEMBL11805',
#  'CHEMBL323655',
#  'CHEMBL110045',
#  'CHEMBL325740',
#  'CHEMBL357843',
#  'CHEMBL346605',
#  'CHEMBL346605',
#  'CHEMBL338492',
#  'CHEMBL140020',
#  'CHEMBL288316',
#  'CHEMBL45005',
#  'CHEMBL45005',
#  'CHEMBL31561',
#  'CHEMBL31561',
#  'CHEMBL138072',
#  'CHEMBL136870',
#  'CHEMBL612100',
#  'CHEMBL139330',
#  'CHEMBL289890',
#  'CHEMBL538352',
#  'CHEMBL54126',
#  'CHEMBL152826',
#  'CHEMBL152826',
#  'CHEMBL286727',
#  'CHEMBL286727',
#  'CHEMBL140403',
#  'CHEMBL347023',
#  'CHEMBL347023',
#  'CHEMBL612098',
#  'CHEMBL139908',
#  'CHEMBL54727',
#  'CHEMBL153848',
#  'CHEMBL153848',
#  'CHEMBL94',
#  'CHEMBL609671',
#  'CHEMBL147213',
#  'CHEMBL358323',
#  'CHEMBL136145',
#  'CHEMBL273904',
#  'CHEMBL273904',
#  'CHEMBL137561',
#  'CHEMBL138988',
#  'CHEMBL136526',
#  'CHEMBL32768',
#  'CHEMBL145971',
#  'CHEMBL352247',
#  'CHEMBL352247',
#  'CHEMBL334938',
#  'CHEMBL146158',
#  'CHEMBL345698',
#  'CHEMBL345698',
#  'CHEMBL341956',
#  'CHEMBL58521',
#  'CHEMBL58521',
#  'CHEMBL156710',
#  'CHEMBL156710',
#  'CHEMBL337142',
#  'CHEMBL136294',
#  'CHEMBL95',
#  'CHEMBL748',
#  'CHEMBL95',
#  'CHEMBL609672',
#  'CHEMBL34000',
#  'CHEMBL347667',
#  'CHEMBL347667',
#  'CHEMBL154155',
#  'CHEMBL154155',
#  'CHEMBL135086',
#  'CHEMBL612099',
#  'CHEMBL422695',
#  'CHEMBL422695',
#  'CHEMBL155191',
#  'CHEMBL155191',
#  'CHEMBL352215',
#  'CHEMBL352215',
#  'CHEMBL342370',
#  'CHEMBL136229',
#  'CHEMBL137226',
#  'CHEMBL136669',
#  'CHEMBL539108',
#  'CHEMBL422338',
#  'CHEMBL422338',
#  'CHEMBL350916',
#  'CHEMBL350916',
#  'CHEMBL125278',
#  'CHEMBL136916',
#  'CHEMBL344196',
#  'CHEMBL136719',
#  'CHEMBL136670',
#  'CHEMBL416772',
#  'CHEMBL156487',
#  'CHEMBL156487',
#  'CHEMBL342903',
#  'CHEMBL134914',
#  'CHEMBL342902',
#  'CHEMBL335108',
#  'CHEMBL609150',
#  'CHEMBL359412',
#  'CHEMBL423419',
#  'CHEMBL423419',
#  'CHEMBL9113',
#  'CHEMBL9113',
#  'CHEMBL155320',
#  'CHEMBL155320',
#  'CHEMBL33332',
#  'CHEMBL155499',
#  'CHEMBL155499',
#  'CHEMBL16645',
#  'CHEMBL16645',
#  'CHEMBL920',
#  'CHEMBL136568',
#  'CHEMBL344924',
#  'CHEMBL343319',
#  'CHEMBL60745',
#  'CHEMBL298312',
#  'CHEMBL298312',
#  'CHEMBL423352',
#  'CHEMBL609149',
#  'CHEMBL32585',
#  'CHEMBL149427',
#  'CHEMBL135503',
#  'CHEMBL137560',
#  'CHEMBL147968',
#  'CHEMBL284692',
#  'CHEMBL440185',
#  'CHEMBL440185',
#  'CHEMBL345031',
#  'CHEMBL94',
#  'CHEMBL609719',
#  'CHEMBL136148',
#  'CHEMBL33101',
#  'CHEMBL154848',
#  'CHEMBL154848',
#  'CHEMBL335439',
#  'CHEMBL344864',
#  'CHEMBL343344',
#  'CHEMBL33051',
#  'CHEMBL422459',
#  'CHEMBL147793',
#  'CHEMBL349791',
#  'CHEMBL349791',
#  'CHEMBL139259',
#  'CHEMBL158242',
#  'CHEMBL158242',
#  'CHEMBL157327',
#  'CHEMBL157327',
#  'CHEMBL114059',
#  'CHEMBL114059',
#  'CHEMBL139684',
#  'CHEMBL609718',
#  'CHEMBL1626784',
#  'CHEMBL609668',
#  'CHEMBL149230',
#  'CHEMBL155371',
#  'CHEMBL155371',
#  'CHEMBL609409',
#  'CHEMBL1128',
#  'CHEMBL1128',
#  'CHEMBL309131',
#  'CHEMBL102637',
#  'CHEMBL102637',
#  'CHEMBL103959',
#  'CHEMBL103959',
#  'CHEMBL435763',
#  'CHEMBL748',
#  'CHEMBL54577',
#  'CHEMBL322628',
#  'CHEMBL322628',
#  'CHEMBL54420',
#  'CHEMBL300143',
#  'CHEMBL102077',
#  'CHEMBL102077',
#  'CHEMBL293720',
#  'CHEMBL304820',
#  'CHEMBL102078',
#  'CHEMBL102078',
#  'CHEMBL318749',
#  'CHEMBL103153',
#  'CHEMBL435763',
#  'CHEMBL311849',
#  'CHEMBL69059',
#  'CHEMBL54470',
#  'CHEMBL19557',
#  'CHEMBL101482',
#  'CHEMBL71740',
#  'CHEMBL2079593',
#  'CHEMBL2079593',
#  'CHEMBL278826',
#  'CHEMBL417915',
#  'CHEMBL70182',
#  'CHEMBL20339',
#  'CHEMBL68953',
#  'CHEMBL55315',
#  'CHEMBL292695',
#  'CHEMBL103890',
#  'CHEMBL53623',
#  'CHEMBL54864',
#  'CHEMBL102226',
#  'CHEMBL102226',
#  'CHEMBL300808',
#  'CHEMBL54014',
#  'CHEMBL294208',
#  'CHEMBL103873',
#  'CHEMBL103873',
#  'CHEMBL65891',
#  'CHEMBL71994',
#  'CHEMBL54956',
#  'CHEMBL67397',
#  'CHEMBL54727',
#  'CHEMBL104891',
#  'CHEMBL104891',
#  'CHEMBL71982',
#  'CHEMBL640',
#  'CHEMBL640',
#  'CHEMBL163362',
#  'CHEMBL165726',
#  'CHEMBL341658',
#  'CHEMBL208599',
#  'CHEMBL659',
#  'CHEMBL341658',
#  'CHEMBL539072',
#  'CHEMBL349977',
#  'CHEMBL95',
#  'CHEMBL357207',
#  'CHEMBL1677',
#  'CHEMBL166194',
#  'CHEMBL541344',
#  'CHEMBL165292',
#  'CHEMBL162734',
#  'CHEMBL140476',
#  'CHEMBL142491',
#  'CHEMBL142816',
#  'CHEMBL143290',
#  'CHEMBL161880',
#  'CHEMBL95',
#  'CHEMBL539051',
#  'CHEMBL208599',
#  'CHEMBL355821',
#  'CHEMBL109869',
#  'CHEMBL433041',
#  'CHEMBL143094',
#  'CHEMBL208599',
#  'CHEMBL1255901',
#  'CHEMBL4524111',
#  'CHEMBL542497',
#  'CHEMBL1255901',
#  'CHEMBL445130',
#  'CHEMBL166359',
#  'CHEMBL350496',
#  'CHEMBL139819',
#  'CHEMBL335355',
#  'CHEMBL341658',
#  'CHEMBL289890',
#  'CHEMBL140476',
#  'CHEMBL1255901',
#  'CHEMBL165304',
#  'CHEMBL140476',
#  'CHEMBL557181',
#  'CHEMBL87014',
#  'CHEMBL107254',
#  'CHEMBL313231',
#  'CHEMBL537908',
#  'CHEMBL502',
#  'CHEMBL106418',
#  'CHEMBL106932',
#  'CHEMBL94',
#  'CHEMBL421601',
#  'CHEMBL104355',
#  'CHEMBL87823',
#  'CHEMBL107673',
#  'CHEMBL87344',
#  'CHEMBL86835',
#  'CHEMBL75121',
#  'CHEMBL104681',
#  'CHEMBL107892',
#  'CHEMBL502',
#  'CHEMBL432376',
#  'CHEMBL321605',
#  'CHEMBL502',
#  'CHEMBL106782',
#  'CHEMBL104334',
#  'CHEMBL94',
#  'CHEMBL320291',
#  'CHEMBL659',
#  'CHEMBL315385',
#  'CHEMBL542543',
#  'CHEMBL85404',
#  'CHEMBL106082',
#  'CHEMBL245079',
#  'CHEMBL555075',
#  'CHEMBL106348',
#  'CHEMBL552832',
#  'CHEMBL318517',
#  'CHEMBL321808',
#  'CHEMBL106936',
#  'CHEMBL327135',
#  'CHEMBL75013',
#  'CHEMBL314989',
#  'CHEMBL95',
#  'CHEMBL106344',
#  'CHEMBL542297',
#  'CHEMBL87273',
#  'CHEMBL86031',
#  'CHEMBL95',
#  'CHEMBL316973',
#  'CHEMBL313582',
#  'CHEMBL108163',
#  'CHEMBL611808',
#  ...]

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
canonical_smiles
# Out:
# ['CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1',
#  'O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1',
#  'CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1',
#  'O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F',
#  'CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C',
#  'CSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)c1ccccc1',
#  'CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)C',
#  'CCCCCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCOCC1',
#  'COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1',
#  'CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)c1ccccc1',
#  'CCSc1nc(-c2ccc(OC)cc2)nn1C(=O)N1CCOCC1',
#  'CSc1nc(-c2ccc3ccccc3c2)nn1C(=O)N(C)C',
#  'C[C@H]1C(=O)N(C(=O)NCc2ccccc2)[C@@H]1Oc1ccc(C(=O)C(C)(C)C)cc1',
#  'CSc1nc(-c2ccc(-c3ccccc3)cc2)nn1C(=O)N(C)C',
#  'CSc1nc(/C=C/c2ccccc2)nn1C(=O)N(C)C',
#  'CCCCCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCCCC1',
#  'CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)c1ccccc1',
#  'Cc1c(C(C)C)c(=O)on1C(=O)N1CCC[C@H](C)C1',
#  'CCSc1nc(-c2ccc(OC)cc2)nn1C(=O)N(C)c1ccccc1',
#  'CCCCCCSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)c1ccccc1',
#  'CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCCCC1',
#  'O=C(N1CCOCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F',
#  'CSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)C',
#  'CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCOCC1',
#  'CCCCCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)c1ccccc1',
#  'CCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)C',
#  'CCCCCCSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)C',
#  'CCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)C',
#  'Cc1ccc(-c2nc(SCC(F)(F)F)n(C(=O)N(C)C)n2)cc1',
#  'COc1nn(-c2ccc(NC(=O)c3ccc(C(C)(C)C)cc3)cc2)c(=O)o1',
#  'CSc1nc(-c2ccc(C(F)(F)F)cc2)nn1C(=O)N(C)C',
#  'C[C@H]1C(=O)N(C(=O)NCc2ccccc2)[C@@H]1Oc1ccc(C(=O)O)cc1',
#  'CSc1nc(-c2ccc(C)cc2)nn1C(=O)N1CCOCC1',
#  'CCN(CC)CCS/C(=N\\O)C(=O)c1ccc(OC)cc1',
#  'CN(C)C(=O)Oc1cccc([N+](C)(C)C)c1.[Br-]',
#  'C[N+](C)(C)CCS/C(=N\\O)C(=O)c1ccc(F)cc1.[Cl-]',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'Cc1ccc(C(=O)/C(=N/O)SCC[N+](C)(C)C)cc1.[Cl-]',
#  'N#CC(C#N)=C1Nc2ccccc2N1CCNCc1ccc(CN2CCCCC2)o1',
#  'COc1cc(N)c(Cl)cc1C(=O)NCCNCc1ccc(CN(C)C)o1',
#  'CCN(CC)CCS/C(=N\\O)C(=O)c1ccc(Cl)cc1.Cl',
#  'CN1CCN(Cc2ccc(CNCCN3CCNC3=C(C#N)C#N)o2)CC1',
#  'Oc1nc2ccccc2n1CCNCc1ccc(CN2CCCCC2)o1',
#  'CC[N+](C)(CC)CCS/C(=N\\O)C(=O)c1ccc(OC)cc1.[Cl-]',
#  'Cc1ccc(C(=O)/C(=N/O)SCCN(C)C)cc1.Cl',
#  'CC1CCCCN1Cc1ccc(CNCCN2CCNC2=C(C#N)C#N)o1',
#  'N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCCCC2)o1',
#  'CNC(NCCNCc1ccc(CN2CCCCC2)o1)=C(C#N)C#N.Cl',
#  'CCN(CC)CCNC(=O)c1cc(Cl)c(N)cc1OC',
#  'COc1ccc(C(=O)/C(=N/O)SCC[N+](C)(C)C)cc1.[Cl-]',
#  'CN(C)CCS/C(=N\\O)C(=O)c1ccc(Cl)cc1.Cl',
#  'N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCC(O)CC2)o1',
#  'CN(C)Cc1ccc(CNCCN2CCNC2=C(C#N)C#N)o1',
#  'CCN(C)Cc1ccc(CNCCN2CCNC2=C(C#N)C#N)o1',
#  'COc1ccc(C(=O)/C(=N/O)SCCN(C)C)cc1',
#  'CCN(CC)Cc1ccc(CNCCN2CCNC2=C(C#N)C#N)o1.Cl',
#  'CN(C)Cc1ccc(CNCCN2CCN/C2=C\\[N+](=O)[O-])o1',
#  'CC[N+](C)(CC)CCS/C(=N\\O)C(=O)c1ccc(Cl)cc1.[Cl-]',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'NC(=O)c1cc[n+](COC[n+]2ccccc2/C=N/O)cc1.[Cl-].[Cl-]',
#  'CNC(NCCNCc1ccc(CN(C)C)o1)=C(C#N)C#N',
#  'CNC(NCCNCc1ccc(CN(C(C)C)C(C)C)o1)=C(C#N)C#N',
#  'CC(C)N(CCS/C(=N\\O)C(=O)c1ccc(Cl)cc1)C(C)C.Cl',
#  'C[n+]1ccccc1C=NO',
#  'CCN(CC)CCS/C(=N\\O)C(=O)c1ccccc1.Cl',
#  'CC1CCN(Cc2ccc(CNCCN3CCNC3=C(C#N)C#N)o2)CC1',
#  'CCN(CC)CCS/C(=N\\O)C(=O)c1ccc(Br)cc1.Cl',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCCC2)o1',
#  'Cl.N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CC=CCC2)o1',
#  'CN(C)CCS/C(=N\\O)C(=O)c1ccc(Br)cc1.Cl',
#  'CCN(CC)CCS/C(=N\\O)C(=O)c1ccc(C#N)cc1.Cl',
#  'CNC(NCCNCc1ccc(COC)o1)=C(C#N)C#N',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CNC(NCCNCc1ccc(CN2CCCC2)o1)=C(C#N)C#N',
#  'N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCOCC2)o1',
#  'N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCSCC2)o1',
#  'CNC(=C[N+](=O)[O-])NCCSCc1ccc(CN(C)C)o1',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CC1CCCN(Cc2ccc(CNCCN3CCNC3=C(C#N)C#N)o2)C1',
#  'CC1CCCC(C)N1Cc1ccc(CNCCN2CCNC2=C(C#N)C#N)o1',
#  'CC[N+](C)(CC)CCS/C(=N\\O)C(=O)c1ccc(F)cc1.[Cl-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'CC[N+](C)(CC)CCS/C(=N\\O)C(=O)c1ccc(C#N)cc1.[Cl-]',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCN4CCOCC4)ccc3N(C)[C@@H]12',
#  'COC1CCCN(Cc2ccc(CNCCN3CCNC3=C(C#N)C#N)o2)C1.Cl',
#  'C[N+](C)(C)CCS/C(=N\\O)C(=O)c1ccc(Br)cc1.[I-]',
#  'N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCCC(O)C2)o1',
#  'C/N=c1\\c(O)c(O)\\c1=N/CCNCc1ccc(CN2CCCCC2)o1',
#  'CN(C)CCCS/C(=N\\O)C(=O)c1ccc(Br)cc1.O=C(O)C(=O)O',
#  'Cl.N#CC(C#N)=C1NCCN1CCNCc1ccc(CN2CCCCCC2)o1',
#  'COc1ccccc1CNCCCCCCNCCSSCCNCCCCCCNCc1ccccc1OC',
#  'COc1ccccc1CNCCCCCCNCCCCCCCNCCCCCCNCc1ccccc1OC',
#  'COc1ccccc1CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(C)Cc1ccccc1OC',
#  'COc1ccccc1CNCCCCCCNCCCCCCNCCCCCCNCc1ccccc1OC',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'COc1ccccc1CNCCCCCCNCCCCCCCCNCCCCCCNCc1ccccc1OC',
#  'COc1ccccc1CNCCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCNCc1ccccc1OC',
#  'NCCCCCCNCCSSCCNCCCCCCN',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'COc1ccccc1CNCCCCCC(=O)NCCCCCCCCNC(=O)CCCCCNCc1ccccc1OC',
#  'COc1ccccc1CNCCCCCCNCCCCCNCCCCCCNCc1ccccc1OC',
#  'NC12CC(C(F)(F)F)=CC(Cc3nc(O)ccc31)/C2=C\\C(F)(F)F',
#  'C[n+]1ccn(COCC(C)(C)[N+](=O)[O-])c1/C=N/O.[Cl-]',
#  'C/C=C1\\C2C=C(C(F)(F)F)CC1(N)c1ccc(O)nc1C2',
#  'C/C=C1\\[C@H]2C=C(C)C[C@@]1(N)c1ccc(=O)[nH]c1C2',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Nc1c2c(nc3ccccc13)-c1ccccc1CO2',
#  'C[n+]1ccccc1/C=N/O.[Cl-]',
#  'Nc1cc(-c2ccccc2)nc2ccccc12',
#  'CN(CCn1cc[n+](C)c1/C=N/O)S(C)(=O)=O.[Cl-]',
#  'C[n+]1ccn(COCCS(C)(=O)=O)c1/C=N/O.[Cl-]',
#  'CC1=CC2Cc3nc(O)ccc3C(N)(C1)/C2=C/C(F)(F)F',
#  'Nc1c2c(nc3ccccc13)-c1ccccc1C2',
#  'Nc1c2c(nc3ccccc13)-c1ccccc1CC2',
#  'Nc1c2c(nc3ccccc13)-c1ccccc1CS2',
#  'C[n+]1ccn(CCN2CCCC2)c1/C=N/O.[Cl-]',
#  'C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NCc3ccccc3)c(Br)c21',
#  'COc1cc2cc(C(=O)CC(O)C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Cl)c21',
#  'COc1cc2cc(C(=O)CC3=CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](Cc4ccccc4)cc3)sc2cc1OC',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(CCOc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'CCC[n+]1ccc(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)cc1.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](CC4CCC4)cc3)sc2cc1OC.[Br-]',
#  'C/N=C1/CCc2c1n(C)c1cc(Cl)c(OC(=O)NC)cc21',
#  'COc1cc2cc(C(=O)CCCCC3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'CC[n+]1ccc(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)cc1.[Br-]',
#  'CNC(=O)Oc1ccc2c(c1)c1c(n2C)/C(=N\\CCc2ccccc2)CC1',
#  'CCCn1c2c(c3c(Br)c(OC(=O)NC)ccc31)CC/C2=N/CC',
#  'COc1cc2cc(C(O)C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(CC#N)CC3)sc2cc1OC.[Br-]',
#  'COCC[N+]1(C)CCC(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)CC1.[Br-]',
#  'COC(=O)c1ccc(C[n+]2ccc(CCC(=O)c3cc4cc(OC)c(OC)cc4s3)cc2)cc1',
#  'CCCCNC(=O)Oc1ccc2c(c1Br)c1c(n2C)/C(=N\\C)CC1',
#  'COc1cc2cc(C(=O)C=C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](Cc4ccc(F)cc4)cc3)sc2cc1OC',
#  'COc1cc2cc(C(=O)CC(OC)C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](CC4CC4)cc3)sc2cc1OC.[Br-]',
#  'C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)cc21',
#  'COc1cc2cc(C(=O)CC3(O)CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(CC4CCCCO4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](C)cc3)sc2cc1OC.[Br-]',
#  'COCC[n+]1ccc(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)cc1',
#  'COc1cc2cc(C(=O)CC(O)CCC3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](Cc4ccsc4)cc3)sc2cc1OC',
#  'CC/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Br)c21',
#  'C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Br)c21',
#  'COC(=O)C[N+]1(C)CCC(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)CC1.[Br-]',
#  'COc1cc2cc(C(=O)CC(O)C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(CC3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'CC/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Cl)c21',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCC/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)cc21',
#  'C=CC[n+]1ccc(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)cc1.[Br-]',
#  'CCOCC[n+]1ccc(CCC(=O)c2cc3cc(OC)c(OC)cc3s2)cc1',
#  'COc1cc2cc(C(=O)CC(O)C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'C/N=C1/CCc2c1n(C)c1ccc(OC(=O)N(C)C)c(Br)c21',
#  'COc1cc2cc(C(=O)CC(O)C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C=C3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCc3cc[n+](Cc4ccc([N+](=O)[O-])o4)cc3)sc2cc1OC.[Br-]',
#  'CC/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)cc21',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(Cc4ccc([N+](=O)[O-])o4)CC3)sc2cc1OC.[Br-]',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(CC(=O)OC(C)(C)C)CC3)sc2cc1OC.[Br-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCNC1N2',
#  'C[C@@]12CCNC1Nc1ccc(OC(=O)Nc3ccccc3)cc12',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2Cc1ccccc1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Nc1c2c(nc3ccccc13)C1CCC2C1',
#  'CN1c2ccc(OC(=O)Nc3ccccc3)cc2[C@]2(C)CCNC12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3NC12',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(Cc3ccccc3)C1N2Cc1ccccc1',
#  'Nc1c2c(nc3c(Cl)cccc13)CCCC2',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCNC1N2C',
#  'Nc1c2c(nc3cccc(Cl)c13)CCCC2',
#  'CNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCN(C)C1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(Cc3ccccc3)C1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2',
#  'Nc1c2c(nc3ccccc13)CCCC2O',
#  'Nc1c2c(nc3cc(Cl)ccc13)C1CCC2C1',
#  'Nc1c2c(nc3cc(Cl)ccc13)CCCC2',
#  'Nc1c2c(nc3c(Cl)cccc13)C1CCC2C1',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'CN1CC[C@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'C[C@]12CCNC1Nc1ccc(OC(=O)Nc3ccccc3)cc12',
#  'CNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCNC1N2',
#  'C[C@@]12CCN(Cc3ccccc3)C1N(Cc1ccccc1)c1ccc(OC(=O)Nc3ccccc3)cc12',
#  'CNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCN(Cc3ccccc3)C1N2Cc1ccccc1',
#  'Nc1c2c(nc3cccc(Cl)c13)C1CCC2C1',
#  'Nc1c2c(nc3ccc(Cl)cc13)CCCC2',
#  'Nc1c2c(nc3ccc(Cl)cc13)C1CCC2C1',
#  'Cl.Cl.O.c1ccc(CN2CCC(CCOc3ccc(-c4ccccc4)nn3)CC2)cc1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Nc1c2c(nc3ccc(Cl)cc13)CCCC2',
#  'Nc1c2c(nc3cccc(Cl)c13)CCCC2',
#  'Nc1c2c(nc3c1CCCO3)CCCC2',
#  'COc1cccc2nc3c(c(N)c12)CCCC3',
#  'Cl.Cl.c1ccc(CN2CCC(CCNc3ccc(-c4ccccc4)nn3)CC2)cc1',
#  'Cl.Cl.O.c1ccc(CN2CCC(CCNc3cc4c(nn3)-c3ccccc3CCC4)CC2)cc1',
#  'Nc1c2c(nc3cccc(F)c13)OCCC2',
#  'Nc1c2c(nc3cnccc13)OCCC2',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Cl.Cl.O.c1ccc(CN2CCC(CCNc3cc4ccc5ccccc5c4nn3)CC2)cc1',
#  'Nc1c2c(nc3c1CCCC3)CCCC2',
#  'Cc1cccc2nc3c(c(N)c12)CCCC3',
#  'Cl.O.c1ccc(CN2CCC(CCN=c3cc4c(n[nH]3)-c3ccccc3C4)CC2)cc1',
#  'Nc1c2c(nc3ccc(Cl)cc13)OCCC2',
#  'Nc1c2c(nc3cccc(F)c13)CCCC2',
#  'Nc1c2c(nc3ncccc13)CCCC2',
#  'Nc1c2c(nc3c1CCC3)CCCC2',
#  'Cl.Cl.c1ccc(CN2CCC(CCSc3ccc(-c4ccccc4)nn3)CC2)cc1',
#  'Nc1c2c(nc3ncccc13)OCCC2',
#  'Nc1c2c(nc3cnccc13)CCCC2',
#  'COc1cccc2nc3c(c(N)c12)CCCO3',
#  'Nc1c2c(nc3ccccc13)OCCC2',
#  'Cc1cc(=NCCC2CCN(Cc3ccccc3)CC2)[nH]nc1-c1ccccc1.Cl.Cl.O',
#  'CCc1cc(=NCCC2CCN(Cc3ccccc3)CC2)[nH]nc1-c1ccccc1.Cl.Cl.O',
#  'Cl.Cl.O.c1ccc(CN2CCC(CCNc3cc4c(nn3)-c3ccccc3CC4)CC2)cc1',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'Nc1c2c(nc3cccc(Cl)c13)OCCC2',
#  'Nc1c2c(nc3c1CCCO3)CCC2',
#  'Cc1cccc2nc3c(c(N)c12)CCCO3',
#  'C=CC[N+](C)(C)c1cccc(OC)c1.[Br-]',
#  'C=CCC[N+](C)(C)c1ccccc1O.[Br-]',
#  'CN(C)C(=O)Oc1cccc([N+](C)(C)C)c1.[Br-]',
#  'COc1ccc([N+](C)(C)Cc2ccccc2)cc1.[Br-]',
#  'C[N+](C)(C)Cc1cccc(O)c1.[Br-]',
#  'COc1ccc(C(=O)COc2ccc([N+](C)(C)Cc3ccccc3)cc2)cc1OC.[Br-]',
#  'COc1ccc(C(=O)CCc2ccc([N+](C)(C)C)cc2)cc1OC.[Br-]',
#  'CC(=O)Oc1ccc([N+](C)(C)Cc2ccccc2)cc1.[Br-]',
#  'C=CC[N+](C)(C)c1ccc(OC(C)=O)cc1.[Br-]',
#  'C[N+](C)(Cc1ccccc1)c1ccccc1O.[Br-]',
#  'C=CC[N+](C)(C)Cc1cccc(O)c1.[Br-]',
#  'COc1ccc(C(=O)CCc2ccc([N+](C)(C)Cc3ccccc3)cc2)cc1OC.[Br-]',
#  'C=CC[N+](C)(C)c1cccc(O)c1.[Br-]',
#  'COc1cccc(C[N+](C)(C)Cc2ccccc2)c1.[Br-]',
#  'COc1cccc([N+](C)(C)Cc2ccccc2)c1.[Br-]',
#  'C=CC[N+](C)(C)c1cccc(OC(C)=O)c1.[Br-]',
#  'COc1cccc(C[N+](C)(C)C)c1.[Br-]',
#  'COc1ccccc1[N+](C)(C)Cc1ccccc1.[Br-]',
#  'C=CC[N+](C)(C)c1ccc(OCC(=O)c2ccc(OC)c(OC)c2)cc1.[Br-]',
#  'COc1ccc(C(=O)CCc2cccc([N+](C)(C)Cc3ccccc3)c2)cc1OC.[Br-]',
#  'C=C(C)C[N+](C)(C)c1ccccc1O.[Br-]',
#  'C=CC[N+](C)(C)c1ccc(OC)cc1.[Br-]',
#  'CC(=O)Oc1ccccc1[N+](C)(C)Cc1ccccc1.[Br-]',
#  'C=CC[N+](C)(C)c1ccccc1O.[Br-]',
#  'COc1ccc(C(=O)COc2cccc([N+](C)(C)C)c2)cc1OC.[Br-]',
#  'COc1ccc(C(=O)COc2cccc([N+](C)(C)Cc3ccccc3)c2)cc1OC.[Br-]',
#  'C=CC[N+](C)(C)Cc1cccc(OC)c1.[Br-]',
#  'C[N+](C)(Cc1ccccc1)Cc1cccc(O)c1.[Br-]',
#  'COc1ccc(C(=O)COc2ccc([N+](C)(C)C)cc2)cc1OC.[Br-]',
#  'C=C(C)C[N+](C)(C)c1ccccc1OC.[Br-]',
#  'C=C(C)C[N+](C)(C)c1cccc(OC)c1.[Br-]',
#  'C[N+](C)(Cc1ccccc1)c1ccc(O)cc1.[Br-]',
#  'CC(=O)Oc1cccc([N+](C)(C)Cc2ccccc2)c1.[Br-]',
#  'CC[N+](C)(C)c1cccc(O)c1.[Br-]',
#  'C=CC[N+](C)(C)c1ccc(O)cc1.[Br-]',
#  'C=CC[N+](C)(C)c1ccccc1OC.[Br-]',
#  'C=C(C)C[N+](C)(C)c1cccc(O)c1.[Br-]',
#  'COc1ccc(C(=O)CCc2cccc([N+](C)(C)C)c2)cc1OC.[Br-]',
#  'C[N+](C)(Cc1ccccc1)c1cccc(O)c1.[Br-]',
#  'C=C(C)C[N+](C)(C)c1ccc(O)cc1.[Br-]',
#  'C[C@@H]1C(=O)N(C(=O)C2CC2)[C@H]2CCN(C(=O)[C@@H]3CCCN3S(=O)(=O)c3cccc4c(N(C)C)cccc34)[C@H]12',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CCc3ccccc3)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CCc3ccccc3)[C@@H]1N2C',
#  'COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)cc1',
#  'COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)cc1',
#  'CCCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CC(=O)N1C(=O)[C@@H](C)[C@@H]2[C@@H]1CCN2C(=O)[C@@H]1CCCN1S(=O)(=O)c1cccc2c(N(C)C)cccc12',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(Cc3ccccc3)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(Cc3ccccc3)[C@@H]1N2C',
#  'C=CCN1CC[C@@]2(C)c3cc(OC(=O)NC)ccc3N(C)[C@@H]12',
#  'C=CCN1CC[C@@]2(C)c3cc(OC(=O)NC)ccc3N(C)[C@@H]12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NC(C)(C)C)ccc3N(C)[C@@H]12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NC(C)(C)C)ccc3N(C)[C@@H]12',
#  'CN(C)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN(C)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)[C@@H]12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)[C@@H]12',
#  'COc1ccc(C(=O)n2cc(/C=C3\\CN(Cc4ccccc4)CCC3=O)c3ccccc32)cc1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cccn1C(=O)c1ccccc1',
#  'O=C1/C(=C/c2ccc[nH]2)CN(Cc2ccccc2)C/C1=C\\c1ccc[nH]1',
#  'N#Cc1ccc(C(=O)n2cc(/C=C3\\CN(Cc4ccccc4)CCC3=O)c3ccccc32)cc1',
#  'O=C1/C(=C/c2cc[nH]c2)CN(Cc2ccccc2)C/C1=C\\c1cc[nH]c1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1c[nH]c2ccc(OCc3ccccc3)cc12',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cn(C(=O)c2ccc(Cl)cc2)c2ccccc12',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cn(C(=O)c2ccc([N+](=O)[O-])cc2)c2ccccc12',
#  'CN1CCC(C2Cc3ccccc3C2=O)CC1',
#  'CN1CCC(CCCC2Cc3ccccc3C2=O)CC1',
#  'COc1ccc2[nH]cc(/C=C3\\CN(Cc4ccccc4)CCC3=O)c2c1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cn(C(=O)c2ccc(F)cc2)c2ccccc12',
#  'COc1ccc2c(c1)c(/C=C1\\CN(Cc3ccccc3)CCC1=O)cn2C(=O)c1ccccc1',
#  'CC(C)(C)OC(=O)n1cc(/C=C2\\CN(Cc3ccccc3)CCC2=O)c2ccccc21',
#  'CN1CCN(CC2Cc3ccccc3C2=O)CC1',
#  'CC(=O)n1cc(/C=C2\\CN(Cc3ccccc3)CCC2=O)c2ccccc21',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'CC1CCN(Cc2cccc3ccccc23)CC1',
#  'CN1CCC(C[C@@H]2Cc3ccccc3C2=O)CC1',
#  'CN1CCC(CC2=Cc3ccccc3C2)CC1',
#  'CN1CCC(CC/C=C2\\Cc3ccccc3C2=O)CC1',
#  'CC1CCN(Cc2ccccc2)CC1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1ccc[nH]1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1ccn(C(=O)c2ccccc2)c1',
#  'CC1CCN(C(=O)c2ccccc2)CC1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cn(C(=O)c2ccccc2)c2ccccc12',
#  'CN1CCC(/C=C/C=C2\\Cc3ccccc3C2=O)CC1',
#  'CC1CCN(Cc2ccccc2[N+](=O)[O-])CC1',
#  'Cc1[nH]c(C)c(/C=C2\\CN(Cc3ccccc3)CCC2=O)c1C=O',
#  'Cc1ccccc1CN1CCC(C)CC1',
#  'CC1CCN(CC2CCCCC2)CC1',
#  'CC1CCN(CC2Cc3ccccc3C2=O)CC1',
#  'CC1CCN(CCc2ccccc2)CC1',
#  'CN1CCC(C[C@H]2Cc3ccccc3C2=O)CC1',
#  'CN(C)C(=O)Oc1cccc([N+](C)(C)C)c1.[Br-]',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1c[nH]c2ccccc12',
#  'CN1CCC(=C2Cc3ccccc3C2=O)CC1',
#  'CC1CCN(Cc2ccc3ccccc3c2)CC1',
#  'CN1CCC(CCN2C(=O)c3ccccc3C2=O)CC1',
#  'CN1CCC(CCC2C(=O)Nc3ccccc3C2=O)CC1',
#  'CN1CCC(/C=C2\\Cc3ccccc3C2=O)CC1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cc[nH]c1',
#  'O=C1CCN(Cc2ccccc2)C/C1=C\\c1cn(Cc2ccccc2)c2ccccc12',
#  'c1ccc(CN2CCC(CCc3nccc4ccccc34)CC2)cc1',
#  'CN(CCCCCNc1ccc(-c2ccccc2)nn1)Cc1ccccc1.Cl',
#  'Cc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)cc1',
#  'c1ccc(CN2CCC(CCc3noc4cc(N5CCOCC5)ccc34)CC2)cc1',
#  'CCc1cccc(CC)c1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'c1ccc(CN2CCC(CNc3noc4ccccc34)CC2)cc1',
#  'CC(C)c1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Cc1cccc(C)c1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Brc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'O=C(Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1)c1ccccc1',
#  'Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'c1ccc(CN2CCC(CCc3noc4ccccc34)CC2)cc1',
#  'CCc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'O=S(=O)(Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1)c1ccccc1',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'Cc1cc(C)cc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)c1',
#  'C(=C/C1CCN(Cc2ccccc2)CC1)\\c1noc2ccccc12',
#  'c1ccc(CN2CCC(CCc3ncnc4ccccc34)CC2)cc1',
#  'COc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'NC(=O)c1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'Cc1cccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)c1',
#  'Cl.c1ccc(-c2ccc(NCCCCCN3CCc4ccccc4C3)nn2)cc1',
#  'Cc1cccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)c1C',
#  'CN(C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C)c1ccccc1',
#  'COc1cccc2c(CCC3CCN(Cc4ccccc4)CC3)noc12',
#  'CNC(=O)Oc1cc2c(cc1C)N(C)[C@H]1N(C)CC[C@@]21C',
#  'Cc1ccc(C)c(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)c1',
#  'COc1ccc2onc(CCC3CCN(Cc4ccccc4)CC3)c2c1',
#  'Oc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Cc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)c(C)c1',
#  'Cc1cc(C)c(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)c(C)c1',
#  'c1ccc(CN2CCC(CCc3n[nH]c4ccccc34)CC2)cc1',
#  'Cc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)cc1C',
#  'c1ccc(CN2CCC(COc3noc4ccccc34)CC2)cc1',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)[C@@H]12',
#  'Cc1cc2c(cc1OC(=O)Nc1ccccc1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN(C)Cc1cc2c(cc1OC(=O)Nc1ccccc1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Cc1ccc2onc(CCC3CCN(Cc4ccccc4)CC3)c2c1',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)cc1',
#  'c1ccc(CN2CCC(CCc3nsc4ccccc34)CC2)cc1',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN(C)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'N#Cc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'CC(=O)Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'Cc1cc2onc(CCC3CCN(Cc4ccccc4)CC3)c2cc1C',
#  'Cl.Cl.c1ccc(CN2CCC(CCNc3ccc(-c4ccccc4)nn3)CC2)cc1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)[C@@H]1C2',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCN(CC)[C@H]1C2',
#  'CCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CC(C)NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CCN(CC)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CN(C(=O)NCc1ccccc1)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CN(C)C(=O)Oc1cccc([N+](C)(C)C)c1.[Br-]',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCc4ccccc4)ccc3N(C)C12',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CC[N+](C)(C)C1N2C.COS(=O)(=O)[O-]',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccc(Cl)cc4)ccc3N(C)C12',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'CN(C)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CC[N+](C)(C)c1cccc(O)c1.[Br-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'C=CC[N+](C)(C)c1ccc(CCC(=O)CCc2ccc([N+](C)(C)CC=C)cc2)cc1',
#  'COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)C2N3C)cc1',
#  'CNC(=O)Oc1cccc(CN(C)CCCCCCCCCOc2ccc3c(=O)c4ccccc4oc3c2)c1.Cl',
#  'CNC(=O)Oc1ccc2c(c1)CN(CCCOc1ccc3c(=O)c4ccccc4oc3c1)CC2.Cl',
#  'CN(CCCOc1ccc2c(=O)c3ccccc3oc2c1)Cc1cccc(OC(=O)NCCCCCCCCN2CCOCC2)c1',
#  'CNC(=O)Oc1cccc(CN(C)CCCOc2ccc3c(=O)c4ccccc4oc3c2)c1',
#  'CNC(=O)Oc1cccc(CN(C)CCCOc2ccc(C(=O)c3ccccc3)cc2)c1.Cl',
#  'CNC(=O)Oc1cccc(CN(C)CCCCCCOc2ccc3c(=O)c4ccccc4oc3c2)c1',
#  'CNC(=O)Oc1cccc(CN(C)CCCOc2ccc3ccccc3c2)c1.Cl',
#  'CN(CCCOc1ccc2c(=O)c3ccccc3oc2c1)Cc1cccc(OC(=O)NCCCCCCCCCN2CCOCC2)c1',
#  'CNC(=O)Oc1cccc(CN(C)CCCCCCCCOc2ccc3c(=O)c4ccccc4oc3c2)c1.Cl',
#  'CN(CCCOc1ccc2c(=O)c3ccccc3oc2c1)Cc1cccc(OC(=O)NCCCCCCN2CCOCC2)c1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1cccc(CN(C)CCCOc2cccc(Cc3ccccc3)c2)c1.Cl',
#  'CNC(=O)Oc1cccc(CN(C)CCCCCCCOc2ccc3c(=O)c4ccccc4oc3c2)c1.Cl',
#  'CNC(=O)Oc1cccc(CN(C)CCCOc2ccc(-c3ccccc3)cc2)c1',
#  'CN(CCCOc1ccc2c(=O)c3ccccc3oc2c1)Cc1cccc(OC(=O)NCCCCCCCN2CCOCC2)c1',
#  'CNC(=O)Oc1cccc(CN(C)CCCOc2ccccc2)c1.Cl',
#  'CNC(=O)Oc1cccc(CN(C)CC#CCOc2ccc3c(=O)c4ccccc4oc3c2)c1.Cl',
#  'CNC(=O)Oc1cccc(CN(C)CCCCCCCCCCOc2ccc3c(=O)c4ccccc4oc3c2)c1.Cl',
#  'COc1ccccc1CNCCCCCCNCCCCCCCCNCCCCCCNCc1ccccc1OC',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3NC12',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C=O',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1C)Cc1ccccc1C',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1Cl)Cc1ccccc1Cl',
#  'CC[N+](C)(CCCCCC(=O)N(CCCCCCCCN(C(=O)CCCCC[N+](C)(CC)Cc1ccccc1OC)C(C)C)C(C)C)Cc1ccccc1OC',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(Cc3ccccc3)C12',
#  'COc1ccc(CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(C)Cc2ccc(OC)cc2)cc1',
#  'CN1CC[C@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(Cc3ccccc3)C12',
#  'CNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCN(C)C1N2Cc1ccccc1',
#  'COc1ccccc1CNCCCCCCNCCSSCCNCCCCCCNCc1ccccc1OC',
#  'CCN(CCCCCC(=O)N(CCCCCCCCN(C(=O)CCCCCN(CC)Cc1ccccc1OC)C(C)C)C(C)C)Cc1ccccc1OC',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-].[I-].[I-]',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-].[I-].[I-]',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-].[I-].[I-]',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-].[I-].[I-]',
#  'COc1ccccc1CN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(Cc1ccccc1OC)C(C)C)C(C)C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2Cc1ccccc1',
#  'COc1cccc(CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(C)Cc2cccc(OC)c2)c1',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1C(F)(F)F)Cc1ccccc1C(F)(F)F',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-]',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-]',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-]',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1[N+](=O)[O-])Cc1ccccc1[N+](=O)[O-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1)Cc1ccccc1',
#  'CCCOc1ccccc1C[N+](C)(CC)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1OCCC',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1C)Cc1ccccc1C',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CCCOc1ccccc1CN(CC)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1OCCC',
#  'CN1CC[C@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'CNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCN(C)C1N2C',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C=O)C12',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1C(F)(F)F)Cc1ccccc1C(F)(F)F',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CCN(CCCCCCOCCCCCCCCOCCCCCCN(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1)Cc1ccccc1',
#  'CNC(=O)Oc1ccc2c(c1)[C@@]1(C)CCN(C)C1N2',
#  'CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)Cc1ccccc1Cl)Cc1ccccc1Cl',
#  'CC[N+](C)(CCCCCCOCCCCCCCCOCCCCCC[N+](C)(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'COc1ccccc1CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(C)Cc1ccccc1OC',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CC[N+](C)(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCC[N+](C)(CC)Cc1ccccc1OC)Cc1ccccc1OC',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2',
#  'CN1CC[C@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3NC12',
#  'Nc1c2c(nc3cc(Cl)ccc13)-c1ccccc1C2',
#  'COc1ccccc1CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(C)Cc1ccccc1OC',
#  'CCCCCCCNc1c2c(nc3cc(Cl)ccc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3cc(Cl)ccc13)CCCC2',
#  'C[C@]12CC[C@H](O)[C@@](C)(CO)C1C[C@H](O)[C@@]1(C)Oc3cc(-c4cccnc4)oc(=O)c3C(=O)C21',
#  'CN1C(=O)Cc2cc3c(CCC4CCN(Cc5ccccc5)CC4)noc3cc21.CS(=O)(=O)O',
#  'COc1ccc2c(c1)-c1nc3ccccc3c(N)c1C2',
#  'CNC(=O)Oc1ccc2c(c1)OC[C@@H]1CC[N+](C)(C)[C@H]21',
#  'Cc1ccc2nc3c(c(N)c2c1)CCCC3',
#  'Cc1ccc2nc3c(c(N)c2c1)CCCC3',
#  'COc1cc2nc3c(c(N)c2cc1OC)CCCC3',
#  'COc1cc2nc3c(c(N)c2cc1OC)CCCC3',
#  'Nc1ccc2c(N)c3c(nc2c1)-c1ccccc1C3',
#  'Nc1c2c(nc3ccc([N+](=O)[O-])cc13)CCCC2',
#  'Nc1c2c(nc3ccc([N+](=O)[O-])cc13)CCCC2',
#  'Nc1ccc2nc3c(c(N)c2c1)Cc1ccccc1-3',
#  'CCCCCCCNc1c2c(nc3cc(F)ccc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3cc(F)ccc13)CCCC2',
#  'CNC(=O)Oc1ccc2c(c1)[C@@H]1[C@@H](CCN1C)CO2',
#  'O=C(O)/C=C\\C(=O)O.O=C1Cc2cc3c(CCC4CCN(Cc5ccccc5)CC4)noc3cc2N1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Cc1ccc2c(N)c3c(nc2c1)CCCC3',
#  'Cc1ccc2c(N)c3c(nc2c1)CCCC3',
#  'CCCCCCCNc1c2c(nc3cc(C)ccc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3cc(C)ccc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3cc([N+](=O)[O-])ccc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3cc([N+](=O)[O-])ccc13)CCCC2',
#  'CNC(=O)Oc1cccc2c1OC[C@@H]1CCN(C)[C@H]21',
#  'COc1cccc(-c2cc3c(c(=O)o2)C(=O)C2[C@@]4(C)CC[C@H](O)[C@@](C)(CO)C4C[C@H](O)[C@@]2(C)O3)c1',
#  'CN1CC[C@H]2COc3c(O)cccc3[C@H]21',
#  'C[C@]12CC[C@H](O)[C@@](C)(CO)C1C[C@H](O)[C@@]1(C)Oc3cc(-c4ccccn4)oc(=O)c3C(=O)C21',
#  'Nc1c2c(nc3ccccc13)-c1ccc(F)cc1C2',
#  'CCCCCCCNc1c2c(nc3ccc(C)cc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3ccc(C)cc13)CCCC2',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'COc1ccc(-c2cc3c(c(=O)o2)C[C@]2(O)[C@@]4(C)C(=O)C=CC(C)(C)[C@]4(O)CC[C@@]2(C)O3)cc1',
#  'Nc1c2c(nc3ccc(Cl)cc13)CCCC2',
#  'Nc1c2c(nc3ccc(Cl)cc13)CCCC2',
#  'C[C@]12CC[C@H](O)[C@@](C)(CO)C1C[C@H](O)[C@@]1(C)Oc3cc(-c4ccc(Cl)nc4)oc(=O)c3C(=O)C21',
#  'CC(=O)Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1.O=C(O)/C=C/C(=O)O',
#  'Cc1ccc2nc3c(c(NCc4ccccc4)c2c1)CCCC3',
#  'Cc1ccc2nc3c(c(NCc4ccccc4)c2c1)CCCC3',
#  'O=C1Cc2cc3onc(CCC4CCN(Cc5ccccc5)CC4)c3cc2N1',
#  'Cc1ccc2c(c1)-c1nc3ccccc3c(N)c1C2',
#  'COc1ccc2c(N)c3c(nc2c1)CCCC3',
#  'COc1ccc2c(N)c3c(nc2c1)CCCC3',
#  'O=C(CCCCCCC(=O)NCCCCCCN1CC[C@H]2COc3ccccc3[C@H]21)NCCCCCCN1CC[C@H]2COc3ccccc3[C@H]21',
#  'O=C1CCc2cc3c(CCC4CCN(Cc5ccccc5)CC4)noc3cc2N1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Cc1cccc2c1Cc1c-2nc2ccccc2c1N',
#  'Nc1c2c(nc3cc([N+](=O)[O-])ccc13)-c1ccccc1C2',
#  'COc1ccc(-c2cc3c(c(=O)o2)C[C@]2(O)[C@@]4(C)C(=O)C=CC(C)(C)[C@]4(O)CC[C@@]2(C)O3)cc1OC',
#  'COc1cc(-c2cc3c(c(=O)o2)C[C@]2(O)[C@@]4(C)C(=O)C=CC(C)(C)[C@]4(O)CC[C@@]2(C)O3)cc(OC)c1OC',
#  'O=C1Cc2c(ccc3c(CCC4CCN(Cc5ccccc5)CC4)noc23)N1',
#  'Nc1c2c(nc3cc(F)ccc13)CCCC2',
#  'Nc1c2c(nc3cc(F)ccc13)CCCC2',
#  'Nc1c2c(nc3ccccc13)-c1ccccc1C2',
#  'COc1ccc(-c2cc3c(c(=O)o2)C(=O)C2[C@@]4(C)CC[C@H](O)[C@@](C)(CO)C4C[C@H](O)[C@@]2(C)O3)cc1OC',
#  'Nc1ccc2nc3c(c(N)c2c1)CCCC3',
#  'Nc1ccc2nc3c(c(N)c2c1)CCCC3',
#  'COc1ccc2c(c1)Cc1c-2nc2ccccc2c1N',
#  'Nc1c2c(nc3cc([N+](=O)[O-])ccc13)CCCC2',
#  'Nc1c2c(nc3cc([N+](=O)[O-])ccc13)CCCC2',
#  'CNC(=O)Oc1cccc2c1OC[C@@H]1CCN(C)[C@H]21',
#  'CNC(=O)Oc1ccc2c(c1)OC[C@@H]1CCN(C)[C@H]21',
#  'C[C@]12CC[C@H](O)[C@@](C)(CO)C1C[C@H](O)[C@@]1(C)Oc3cc(-c4ccncc4)oc(=O)c3C(=O)C21',
#  'CNC(=O)Oc1cccc2c1OC[C@@H]1CCN(C)[C@H]21',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'COc1cccc2c1Cc1c-2nc2ccccc2c1N',
#  'CCCCCCCNc1c2c(nc3cc(OC)ccc13)CCCC2',
#  'CCCCCCCNc1c2c(nc3cc(OC)ccc13)CCCC2',
#  'Nc1c2c(nc3cc(Cl)ccc13)CCCC2',
#  'Nc1c2c(nc3cc(Cl)ccc13)CCCC2',
#  'Nc1c2c(nc3cc(Br)ccc13)CCCC2',
#  'COc1ccc(-c2cc3c(c(=O)o2)C(=O)C2[C@@]4(C)CC[C@H](O)[C@@](C)(CO)C4C[C@H](O)[C@@]2(C)O3)cc1',
#  'Nc1c2c(nc3ccccc13)-c1ccc(Cl)cc1C2',
#  'Clc1ccc2c(NCc3ccccc3)c3c(nc2c1)CCCC3',
#  'Clc1ccc2c(NCc3ccccc3)c3c(nc2c1)CCCC3',
#  'Nc1c2c(nc3cc(F)ccc13)-c1ccccc1C2',
#  'Nc1c2c(nc3cc(Cl)c(Cl)cc13)CCCC2',
#  'Nc1c2c(nc3cc(Cl)c(Cl)cc13)CCCC2',
#  'O=[N+]([O-])c1ccc2nc3c(c(NCc4ccccc4)c2c1)CCCC3',
#  'O=[N+]([O-])c1ccc2nc3c(c(NCc4ccccc4)c2c1)CCCC3',
#  'C[C@]12CC[C@H](O)[C@@](C)(CO)C1C[C@H](O)[C@@]1(C)Oc3cc(-c4ccccc4)oc(=O)c3C(=O)C21',
#  'Cc1ccc2c(NCc3ccccc3)c3c(nc2c1)CCCC3',
#  'Cc1ccc2c(NCc3ccccc3)c3c(nc2c1)CCCC3',
#  'O=[N+]([O-])c1ccc2c(NCc3ccccc3)c3c(nc2c1)CCCC3',
#  'O=[N+]([O-])c1ccc2c(NCc3ccccc3)c3c(nc2c1)CCCC3',
#  'CN(C)c1ccc(CC(=O)NCCCCCCCCNC23CC4CC(CC(C4)C2)C3)cc1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'CN(C)c1ccc(CC(=O)NCCCCCCCCCCNC23CC4CC(CC(C4)C2)C3)cc1',
#  'CN(C)c1ccc(CC(=O)NCCCCCCCCCCCCNC23CC4CC(CC(C4)C2)C3)cc1',
#  'CC(C)c1ccc(NC(=O)N2CCC[C@H]2C(=O)N2CC[C@H]3[C@H]2[C@H](C)C(=O)N3C(=O)[C@H]2[C@@H](C)[C@H]2C)cc1',
#  'CC(C)c1ccc(NC(=O)N2CCC[C@H]2C(=O)N2CC[C@H]3[C@H]2[C@H](C)C(=O)N3c2nc3ccccc3s2)cc1',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)[C@@H]2N3C)cc1.O=C(O)C(O)C(O)C(=O)O',
#  'C#CC(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C#CCCCC[n+]1cn(C)c(/C=N/O)n1.[Cl-]',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)O[C@@H]2N3C)cc1',
#  'CC#CC(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'COc1ccc2c3c1O[C@H]1C[C@@H](O)C=C[C@@]31CCN(C)C2',
#  'C#CCCOC[n+]1ccn(C)c1C.[Cl-]',
#  'CC#CC(C)(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C#CCCCC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C.O=C(O)c1ccccc1O',
#  'C#CCCOC[n+]1ccc(/C=N/O)cc1.[Cl-]',
#  'C#CCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C#CCCOC[n+]1ccn(C(C)(C)C)c1/C=N/O.[Cl-]',
#  'C#CC1CCCCC1OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C#CCCCC[n+]1ccn(COC)c1/C=N/O.[Cl-]',
#  'C#CCCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C/C=C1\\[C@H]2C=C(C)C[C@@]1(N)c1ccc(=O)[nH]c1C2',
#  'CCN(C)C(=O)Oc1cccc([C@H](C)N(C)C)c1',
#  'C#CC(C)C(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'CC#CCCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C#CCCCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)O[C@@H]1N2C',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CC[N@@+](C)([O-])[C@@H]2N3C)cc1.Cl',
#  'C#CCC(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C[n+]1ccccc1/C=N/O.[Cl-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)O[C@@H]1N2C',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CC[N@@+](C)([O-])[C@@H]1N2C.Cl',
#  'C#CC(C)(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'CCc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CC[N@@+](C)([O-])[C@@H]1N2C.Cl',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C.O=C(O)C(O)C(O)C(=O)O',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CC[N@@+](C)([O-])[C@@H]1N2C.Cl',
#  'C#CC(CC)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'C#CCCCC[n+]1ccccc1/C=N/O.[Cl-]',
#  'C#CCC(CCC)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)[C@@H]12.O=C(O)C(O)C(O)C(=O)O',
#  'CCc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C.O=C(O)C(O)C(O)C(=O)O',
#  'CCc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)O[C@@H]1N2C',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'C#CCCCC[n+]1ccn(C(C)(C)C)c1/C=N/O.[Cl-]',
#  'C#CC(CCC)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'C#CCCCC[n+]1ccc(/C=N/O)cc1.[Cl-]',
#  'C#CC1(OC[n+]2ccn(C)c2/C=N/O)CCCC1.[Cl-]',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)[C@H]2O1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CN1c2ccc(OC(=O)Nc3ccccc3)cc2[C@]2(C)CC[N@@+](C)([O-])[C@H]12.Cl',
#  'Cc1cc2onc(CCC3CCN(Cc4ccccc4)CC3)c2cc1C',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'c1ccc(CN2CCC(CCc3noc4ccccc34)CC2)cc1',
#  'COc1cccc2c(CCC3CCN(Cc4ccccc4)CC3)noc12',
#  'c1ccc(CN2CCC(CCc3noc4cc(N5CCOCC5)ccc34)CC2)cc1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'O=S(=O)(Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1)c1ccccc1',
#  'c1ccc(CN2CCC(CCc3n[nH]c4ccccc34)CC2)cc1',
#  'Cc1ccc2onc(CCC3CCN(Cc4ccccc4)CC3)c2c1',
#  'COc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'C(=C\\C1CCN(Cc2ccccc2)CC1)\\c1noc2ccccc12',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'c1ccc(CN2CCC(CCc3ncnc4ccccc34)CC2)cc1',
#  'Brc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'c1ccc(CN2CCC(CCc3nsc4ccccc34)CC2)cc1',
#  'c1ccc(CN2CCC(CCCc3noc4ccccc34)CC2)cc1',
#  'c1ccc(CN2CCC(CCNc3noc4ccccc34)CC2)cc1',
#  'NC(=O)c1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'c1ccc(CN2CCC(CCc3nccc4ccccc34)CC2)cc1',
#  'c1ccc(CN2CCC(CNc3noc4ccccc34)CC2)cc1',
#  'Oc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'O=C(Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1)c1ccccc1',
#  'N#Cc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'CC(=O)Nc1ccc2c(CCC3CCN(Cc4ccccc4)CC3)noc2c1',
#  'COc1ccc2onc(CCC3CCN(Cc4ccccc4)CC3)c2c1',
#  'c1ccc(CN2CCC(COc3noc4ccccc34)CC2)cc1',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CCC)C1C2.Cc1ccc(C(=O)OC(C(=O)O)C(OC(=O)c2ccc(C)cc2)C(=O)O)cc1.O',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(Cc3ccccc3)C1C2',
#  'CCN1CC[C@@]2(C)c3cc(OC(=O)NC(C)(C)C)ccc3CC12',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CCC)C1C2',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1C2',
#  'CCN1CC[C@@]2(C)c3cc(OC(=O)N[C@@H](C)c4ccccc4)ccc3CC12',
#  'CCN1CC[C@H]2c3cc(OC(=O)NC)ccc3CC21',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CCC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCN1CC[C@@]2(C)c3cc(OC(=O)NCc4ccccc4)ccc3CC12',
#  'CCCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CC)C1C2',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCN1CCCC(c2cccc(OC(=O)NC(C)C)c2)C1',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CCC)C1C2',
#  'CCN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3CC12',
#  'CCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CCC)C1C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCCCCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CC)C1C2',
#  'CCN1CC[C@@]2(C)c3cc(OC(=O)NC)ccc3CC12',
#  'CCCNC(=O)Oc1ccc2c(c1)[C@@H]1CCN(CC)C1C2',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'Nc1c2c(nc3ccccc13)CCCC2O',
#  'Nc1c2c(nc3ccccc13)CCCC2O',
#  'Nc1c2c(nc3ccccc13)CC(O)CC2',
#  'Nc1c2c(nc3ccccc13)CC(O)CC2',
#  'Nc1c2c(nc3ccccc13)CCC(O)C2',
#  'Nc1c2c(nc3ccccc13)CCC(O)C2',
#  'Nc1c2c(nc3ccccc13)C(O)CCC2',
#  'Nc1c2c(nc3ccccc13)C(O)CCC2',
#  'COc1ccccc1CN1CCCCCCCCN(Cc2ccccc2OC)C(=O)CCCCCNCc2ccc(cc2)CNCCCCCC1=O',
#  'CCCCCCCCCN(Cc1ccccc1OC)C(=O)CCCCCN(C)Cc1ccc(-c2ccc(CN(C)CCCCCC(=O)NCc3ccccc3OC)cc2)cc1',
#  'COc1ccccc1CNCCCCCCNCCCCCCCCNCCCCCCNCc1ccccc1OC',
#  'CCCCCCCCCN(Cc1ccccc1OC)C(=O)CCCCCNCc1ccc(-c2ccc(-c3ccc(CNCCCCCC(=O)NCc4ccccc4OC)cc3)cc2)cc1',
#  'COc1ccccc1CN1CCCCCCCCN(Cc2ccccc2OC)C(=O)CCCCCNCc2ccc(cc2)-c2ccc(cc2)CNCCCCCC1=O',
#  'COc1ccccc1CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(C)Cc1ccccc1OC',
#  'COc1ccccc1CN(CCCCCCCCN(Cc1ccccc1OC)C(=O)CCCCCN)C(=O)CCCCCN',
#  'COc1ccccc1CN1CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(Cc2ccccc2OC)Cc2ccc(cc2)-c2ccc(cc2)C1',
#  'COc1ccccc1CN1CCCCCCCCN(Cc2ccccc2OC)C(=O)CCCCCNCc2cccc(c2)Cc2cccc(c2)CNCCCCCC1=O',
#  'CC(OC[n+]1ccn(C)c1/C=N/O)C1CCCCC1.[Cl-]',
#  'Cc1ccc(F)cc1',
#  'Cc1ccc(F)cc1',
#  'CC(=O)Oc1ccc(C)c([N+](C)(C)C)c1',
#  'C=CC[N+](C)(C)c1ccc(CCC(=O)CCc2ccc([N+](C)(C)CC=C)cc2)cc1',
#  'CC(C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'Cc1ccccc1C',
#  'Cc1ccccc1C',
#  'Cc1ccc(C)cc1',
#  'Cc1ccc(C)cc1',
#  'CCC(=O)Oc1cc([N+](C)(C)C)ccc1C',
#  'COc1ccc(C)c([N+](C)(C)C)c1',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)NCc4ccccc4)ccc3N(C)C12',
#  'CC(=O)Oc1cc([N+](C)(C)C)ccc1C',
#  'COC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'Cn1cc[n+](COC[n+]2ccccc2/C=N/O)c1/C=N/O.[Cl-].[Cl-]',
#  'CN(C)C(=O)Oc1cccc([N+](C)(C)C)c1.[Br-]',
#  'COc1cc2c(c(OC)c1)C(=O)C(C)C2',
#  'COc1cc2c(c(OC)c1)C(=O)C(C)C2',
#  'Cc1cccc(C)c1',
#  'Cc1cccc(C)c1',
#  'C=CCCC[N+](C)(C)C',
#  'COc1ccc2c(c1)C(=O)C(C)C2',
#  'COc1ccc2c(c1)C(=O)C(C)C2',
#  'CCN(CC)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CCCC(=O)SCC[N+](C)(C)C',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'COc1cc2c(cc1OC(C)C)CC(C)C2=O',
#  'COc1cc2c(cc1OC(C)C)CC(C)C2=O',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CC(CC(C)(C)C)OC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'COC[n+]1c(/C=N/O)n(C)c2ccccc21.[Cl-]',
#  'C[N+](C)(C)CCS',
#  'COc1ccc(C)cc1OC',
#  'COc1ccc(C)cc1OC',
#  'Cc1ccc(O)cc1[N+](C)(C)C',
#  'COc1cc([N+](C)(C)C)ccc1C',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CC[N+](C)(C)C1N2C',
#  'CCCCCCCCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'Cn1cc[n+](COCC2CCCc3ccccc32)c1/C=N/O.[Cl-]',
#  'Cc1cccc2c1CC(C)C2=O',
#  'Cc1cccc2c1CC(C)C2=O',
#  'C[N+]1(C)CCO[C@@](O)(c2ccc(C#N)cc2)C1',
#  'Cn1cc[n+](COC[n+]2ccn(C)c2/C=N/O)c1/C=N/O',
#  'Cc1cccc(F)c1',
#  'Cc1cccc(F)c1',
#  'C[N+](C)(C)CCCl',
#  'Cc1ccc(N)cc1',
#  'Cc1ccc(N)cc1',
#  'COc1cc(C)cc(OC)c1OC',
#  'COc1cc(C)cc(OC)c1OC',
#  'C[N+](C)(C)CCCCI',
#  'CCC(=O)Oc1cccc([N+](C)(C)C)c1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'C[n+]1ccccc1/C=N/O.[Cl-]',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CC(C)NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'Cn1cc[n+](COCCCc2ccccc2)c1/C=N/O.[Cl-]',
#  'COc1cc2c(cc1O)C(=O)C(C)C2',
#  'COc1cc2c(cc1O)C(=O)C(C)C2',
#  'COc1ccc(C)cc1',
#  'COc1ccc(C)cc1',
#  'C=CCC[N+](C)(C)C',
#  'CN(C(=O)NCc1ccccc1)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CC1Cc2cc3c(cc2C1=O)OCO3',
#  'CC1Cc2cc3c(cc2C1=O)OCO3',
#  'CC1Cc2ccccc2C1=O',
#  'CC1Cc2ccccc2C1=O',
#  'Cc1ccccc1F',
#  'Cc1ccccc1F',
#  'CC(=O)Nc1ccc([C@@]2(O)C[N+](C)(C)CCO2)cc1',
#  'CCCCCC[N+](C)(C)C',
#  'CC(=O)Nc1cccc([N+](C)(C)C)c1',
#  'CCC(=O)Oc1ccc(C)c([N+](C)(C)C)c1',
#  'O/N=C\\c1cccc[n+]1COCCOC[n+]1ccccc1/C=N/O.[Cl-].[Cl-]',
#  'COc1cccc2c1CC(C)C2=O',
#  'COc1cccc2c1CC(C)C2=O',
#  'COc1ccc2c(c1OC)C(=O)C(C)C2',
#  'COc1ccc2c(c1OC)C(=O)C(C)C2',
#  'NC(=O)O',
#  'CC(=O)CCC[N+](C)(C)C',
#  'C[N+](C)(C)CCCCCBr',
#  'CC(=O)Oc1cccc([N+](C)(C)C)c1C',
#  'CCC(=O)Oc1cccc([N+](C)(C)C)c1C',
#  'CCCCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'COc1cc2c(cc1O)CC(C)C2=O',
#  'COc1cc2c(cc1O)CC(C)C2=O',
#  'C[C@@]1(O)C[N+](C)(C)CCO1',
#  'CCOCC[N+](C)(C)C',
#  'CCCC(=O)OCC[N+](C)(C)C',
#  'COc1cccc([N+](C)(C)C)c1C',
#  'CCCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'Cn1cc[n+](COCC2CCCCC2)c1/C=N/O.[Cl-]',
#  'COc1ccc(OC)c2c1CC(C)C2=O',
#  'COc1ccc(OC)c2c1CC(C)C2=O',
#  'Cc1ccccc1',
#  'Cc1ccccc1',
#  'Cc1ccc([N+](=O)[O-])cc1',
#  'Cc1ccc([N+](=O)[O-])cc1',
#  'Cn1cc[n+](COCc2cccc3ccccc23)c1/C=N/O.[Cl-]',
#  'CC1Cc2ccc(F)cc2C1=O',
#  'CC1Cc2ccc(F)cc2C1=O',
#  'Cc1ccc(O)cc1',
#  'Cc1ccc(O)cc1',
#  'C[N+](C)(C)CCO',
#  'CCSCC[N+](C)(C)C',
#  'C[N+](C)(C)CCCCBr',
#  'Cc1c(O)cccc1[N+](C)(C)C',
#  'CC[N+](C)(C)c1cccc(O)c1.[Br-]',
#  'Cc1cccc(O)c1',
#  'Cc1cccc(O)c1',
#  'CC(C)(C)[C@@]1(O)C[N+](C)(C)CCO1',
#  'CN(C)C(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CC(OC[n+]1ccn(C)c1/C=N/O)C(C)(C)C.[Cl-]',
#  'Cn1c(/C=N/O)[n+](C)c2ccccc21.[Cl-]',
#  'C=CC[N+](C)(C)C',
#  'Cc1ccc([N+](C)(C)C)cc1O',
#  'CCCCCCOC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'Cn1cc[n+](COCc2ccccc2)c1/C=N/O.[Cl-]',
#  'COc1cc2c(c(OC)c1OC)C(=O)C(C)C2',
#  'COc1cc2c(c(OC)c1OC)C(=O)C(C)C2',
#  'C[N+]1(C)CCO[C@H](O)C1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'C[N+]1(C)CCO[C@@](O)(c2ccc([N+](=O)[O-])cc2)C1.[Cl-]',
#  'COc1cccc([N+](C)(C)C)c1',
#  'Cn1cc[n+](COCC(C)(C)C)c1/C=N/O.[Cl-]',
#  'COc1cc2c(cc1OC)C(=O)C(C)C2',
#  'COc1cc2c(cc1OC)C(=O)C(C)C2',
#  'C[N+]1(C)CCO[C@@](O)(c2ccc(Cl)cc2)C1',
#  'C[N+]1(C)CCO[C@@](O)(C(F)(F)F)C1',
#  'CC(=O)Oc1cccc([N+](C)(C)C)c1',
#  'NC(=O)c1cc[n+](COC[n+]2ccccc2/C=N/O)cc1.[Cl-].[Cl-]',
#  'C[N+](C)(C)c1cccc(O)c1',
#  'Cc1n(C)cc[n+]1COC(C)C(C)(C)C.[Cl-]',
#  'COc1cccc(C)c1',
#  'COc1cccc(C)c1',
#  'C[N+]1(C)CCO[C@@](O)(c2ccc(N)cc2)C1',
#  'CCOc1cc2c(cc1OCC)C(=O)C(C)C2',
#  'CCOc1cc2c(cc1OCC)C(=O)C(C)C2',
#  'Cc1ccc2c(c1)C(=O)C(C)C2',
#  'Cc1ccc2c(c1)C(=O)C(C)C2',
#  'Cc1cccc([N+](=O)[O-])c1',
#  'Cc1cccc([N+](=O)[O-])c1',
#  'C[N+](C)(C)CCCBr',
#  'C[N+](C)(C)c1cccc([N+](=O)[O-])c1.[Cl-]',
#  'C[N+](C)(C)c1cccc(N)c1',
#  'COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)C2N3C)cc1',
#  'CCC(OC[n+]1ccn(C)c1/C=N/O)C(C)(C)C.[Cl-]',
#  'COc1ccc2c(c1OC)CC(C)C2=O',
#  'COc1ccc2c(c1OC)CC(C)C2=O',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccc(Cl)cc4)ccc3N(C)C12',
#  'CC[N+](C)(C)c1cccc(O)c1.[Cl-]',
#  'CC[N+](C)(C)c1cccc(O)c1.[Cl-]',
#  'O/N=C/c1nc(-c2cccc3ccccc23)no1',
#  'CCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCc1ccc(SC(=O)OCC[N+](C)(C)C)cc1.[Cl-]',
#  'CCc1ccc(SC(=O)OCC[N+](C)(C)C)cc1.[Cl-]',
#  'O/N=C/c1nc(-c2ccccc2)no1',
#  'C[n+]1ccccc1/C=N/O.[Cl-]',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(CCc4ccccc4)C2N3C)cc1',
#  'CC(C)CCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CC(C)CCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCNC2N3C)cc1',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#  'CCCCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)C2N3Cc2ccccc2)cc1',
#  'O/N=C/c1nc(-c2cccs2)no1',
#  'CCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'C[N+](C)(C)CCOC(=O)Sc1ccccc1.[Cl-]',
#  'CCc1ccccc1SC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'O/N=C/c1nc(-c2ccccc2)no1',
#  'C[n+]1c(/C=N/O)cccc1CCO[n+]1ccc(C(N)=O)cc1.[Cl-].[Cl-]',
#  'CCN(CC)CC/N=C(\\NO)c1nc(-c2ccccc2)no1',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCNC2N3)cc1',
#  'CCN(CC)CCS/C(=N\\O)c1nc(C)no1',
#  'CCC(C)CSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCCCCCCc1noc(/C(=N/O)SCCN(CC)CC)n1',
#  'Cc1noc(/C=N\\O)n1',
#  'Cc1noc(/C=N\\O)n1',
#  'Cc1noc(/C=N/O)n1',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)C2N3C)cc1',
#  'O/N=C/c1nc(Cc2ccccc2)no1',
#  'CCN(CC)CCS/C(=N\\O)c1nc(-c2ccccc2)no1',
#  'CC(C)(C)c1noc(/C=N/O)n1',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(Cc3ccccc3)C1N2Cc1ccccc1',
#  'CCC(C)(C)SC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCNC1N2C',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCNC1N2',
#  'CCCCCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCCCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(Cc4ccccc4)C2N3Cc2ccccc2)cc1',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2Cc1ccccc1',
#  'CC(C)c1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(C)CCN(C)C2N3)cc1',
#  'CCCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCN(CC)CCS/C(=N\\O)c1nc(C(C)(C)C)no1',
#  'CCN(CC)CCS/C(=N\\O)c1nc(Cc2ccccc2)no1',
#  'Cc1ccccc1NC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(CCc3ccccc3)C1N2C',
#  'O/N=C/c1nc(-c2ccncc2)no1',
#  'CN1CC[C@@]2(C)c3cc(OC(=O)Nc4ccccc4)ccc3N(C)C12',
#  'CCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCSC(=O)OCC[N+](C)(C)C.[Cl-]',
#  'CCCCCCCCc1noc(/C=N/O)n1',
#  'CCN(CC)CCNC(=O)c1ccc(N)cc1',
#  'CCN(CC)CCNC(=O)c1ccc(N)cc1',
#  'c1ccc2c(c1)CN1CCCCC1=N2',
#  'Clc1ccc2c(c1)CN1CCCCCC1=N2',
#  'CCC1=CC2Cc3nc4cc(F)ccc4c(N)c3C(C1)C2',
#  'CCC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3[C@@H](C1)C2',
#  'COc1ccc2c3c1O[C@H]1C[C@@H](O)C=C[C@@]31CCN(C)C2',
#  'CCC1=CC2Cc3nc4cc(F)ccc4c(N)c3C(C1)C2',
#  'CC1=CC2CC(C1)Cc1nc3ccccc3c(N)c12.Cl',
#  'Clc1cccc2c1N=C1CCCCCN1C2',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CCC1=CC2Cc3nc4cc(Cl)cc(Cl)c4c(N)c3C(C1)C2',
#  'Cl.Nc1c2c(nc3ccccc13)CCCC2',
#  'N=c1c2ccc(Cl)cc2nc2n1CCCCC2',
#  'CC1=CC2Cc3nc4ccccc4c(N)c3C(C1)C2.Cl',
#  'O=c1c2ccc(Cl)cc2nc2n1CCCCC2',
#  'c1ccc2c(c1)CN1CCCCCCC1=N2',
#  'CC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3C(C1)C2',
#  'CCC1=CC2Cc3nc4cccc(F)c4c(N)c3C(C1)C2',
#  'CCC1=CC2Cc3nc4ccc(Cl)cc4c(N)c3C(C1)C2',
#  'CC1=CC2Cc3nc4cc(F)cc(F)c4c(N)c3C(C1)C2',
#  'Clc1cccc2c1CN1CCCCCC1=N2',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CCC1=CC2Cc3nc4ccccc4c(N)c3C(C1)C2.Cl',
#  'CCC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3[C@@H](C1)C2',
#  'c1ccc2c(c1)CN1CCCC1=N2',
#  'CC1=CC2Cc3nc4cccc(F)c4c(N)c3C(C1)C2',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CCC1=CC2Cc3nc4cc(C)cc(C)c4c(N)c3C(C1)C2',
#  'CCC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3[C@@H](C1)C2',
#  'C/C=C1\\[C@H]2C=C(C)C[C@@]1(N)c1ccc(=O)[nH]c1C2',
#  'CC1=C[C@@H]2Cc3nc4cc(F)ccc4c(N)c3[C@H](C1)C2',
#  'CCC1=CC2CC(C1)Cc1nc3ccccc3c(N)c12.Cl',
#  'C/C=C1\\[C@H]2C=C(C)C[C@@]1(N)c1ccc(=O)[nH]c1C2',
#  'Clc1ccc2c(c1)N=C1CCCCCN1C2',
#  'c1ccc2c(c1)CN1CCCCCCCC1=N2',
#  'S=c1c2ccc(Cl)cc2nc2n1CCCCC2',
#  'CCC1=CC2Cc3nc4cccc(Cl)c4c(N)c3C(C1)C2',
#  'CCC1=CC2Cc3nc4cc(F)cc(F)c4c(N)c3C(C1)C2',
#  'CCC1=CC2Cc3nc4cc(F)ccc4c(N)c3C(C1)C2',
#  'COC[n+]1ccn(C)c1/C=N/O.[Cl-]',
#  'CC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3C(C1)C2',
#  'C/C=C1\\[C@H]2C=C(C)C[C@@]1(N)c1ccc(=O)[nH]c1C2',
#  'c1ccc2c(c1)CN1CCCCCC1=N2',
#  'CC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3C(C1)C2',
#  'Cl.O=C(CCC1CCN(Cc2ccccc2)CC1)c1ccc2c(c1)OCCO2',
#  'Cc1cc(C(=O)CCC2CC[N+](C)(Cc3ccccc3)CC2)nn1-c1ccccc1',
#  'CN(C)Cc1ccc(CSCCNc2cc(Nc3ccc(F)cc3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)OCO3)CC1',
#  'Cl.O=C(CCC1CCN(Cc2ccccc2)CC1)c1ccc2[nH]c(-c3ccccc3)nc2c1',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'CCCCCNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'CC(C)=NNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CN(C)Cc1ccc(CSCCNc2cccc(F)c2C#N)o1',
#  'CN(C)Cc1ccc(CSCCNc2ccc(F)cc2[N+](=O)[O-])o1',
#  'COc1ccc2cc(C(=O)CCC3CC[N+](C)(Cc4ccccc4)CC3)ccc2c1',
#  'CN(C)Cc1ccc(CSCCNc2cc(NCc3cccnc3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)CCO3)CC1',
#  'C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)CCO3)CC1',
#  'COc1cc2cc(-c3ccc(CN(C)Cc4ccccc4)cc3)c(=O)oc2cc1OC',
#  'CN(C)Cc1ccc(CSCCNc2cc(F)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'CN(C)Cc1ccc(CSCCNc2cc(N)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(Cc4ccccc4)CC3)n(C)c2cc1OC',
#  'CN(C)Cc1ccc(CSCCNc2cc(NN)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2',
#  'CCCNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'CN(C)Cc1ccc(CSCCNc2cc(Nc3ncccc3[N+](=O)[O-])c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C',
#  'CNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'COc1ccc2c3c1O[C@H]1C[C@@H](O)C=C[C@@]31CCN(C)C2',
#  'C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)NCCCC3)CC1',
#  'Cc1nc2ccc(C(=O)CCC3CCN(Cc4ccccc4)CC3)cc2s1.Cl',
#  'COc1ccc2c3c1OC1C[C@@H](O)C=C[C@@]31CC[N+](C)(C)C2',
#  'CN(C)Cc1ccc(CSCCNc2cc(Nc3ccccc3C#N)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'CC1=C[C@H]2Cc3[nH]c(=O)ccc3[C@]3(C1)NCCC[C@H]23',
#  'CCn1c(C)nc2cc(C(=O)CCC3CCN(Cc4ccccc4)CC3)ccc21.Cl',
#  'CN(C)CCNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'Cl.O=C(CCC1CCN(Cc2ccccc2)CC1)c1ccccc1',
#  'CN(C)Cc1ccc(CSCCNc2cc(NCCCN3CCOCC3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'CN(C)Cc1ccc(CSCCNc2nnccc2[N+](=O)[O-])o1',
#  'CN(C)Cc1ccc(CSCCNc2cc(NCc3ccccc3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'CN(C)Cc1ccc(CSCCNc2cc(Oc3ccc([N+](=O)[O-])cc3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'O=C(CCC1CCN(Cc2ccccc2)CC1)c1ccc2c(c1)NCCCC2',
#  'COc1cc2c(cc1OC)C(=O)C(CC1CC[N+](C)(Cc3ccccc3)CC1)C2',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CN(C)Cc1ccc(CSCCNc2cc(NCc3ccccn3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'Cc1nc2cc(C(=O)CCC3CCN(Cc4ccccc4)CC3)ccc2[nH]1.Cl',
#  'COc1cc2cc(C(=O)CCC3CC[N+](C)(Cc4ccccc4)CC3)sc2cc1OC',
#  'C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)OCCO3)CC1',
#  'Nc1c2c(nc3ccccc13)CCCC2',
#  'CN(C)Cc1ccc(CSCCNc2ccc([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)CCCCO3)CC1',
#  'CN(C)Cc1ccc(CSCCNc2cc(Nc3ccccc3)c([N+](=O)[O-])cc2[N+](=O)[O-])o1',
#  'CC1=CC2Cc3nc(O)ccc3C3(C1)C2CCCN3C',
#  ...]

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
standard_value
# Out:
# ['750.0',
#  '100.0',
#  '50000.0',
#  '300.0',
#  '800.0',
#  '2400.0',
#  '100.0',
#  '50000.0',
#  '800.0',
#  '50000.0',
#  '50000.0',
#  '50.0',
#  '100000.0',
#  '560.0',
#  '10.0',
#  '10.0',
#  '1400.0',
#  '17000.0',
#  '1100.0',
#  '50000.0',
#  '26.0',
#  '50000.0',
#  '800.0',
#  '50000.0',
#  '50000.0',
#  '56.0',
#  '200.0',
#  '300.0',
#  '200.0',
#  '50000.0',
#  '500.0',
#  '100000.0',
#  '50000.0',
#  '260000.0',
#  '22.0',
#  '1000000.0',
#  '3800.0',
#  '40.0',
#  '1000000.0',
#  '73.0',
#  '3100.0',
#  '520000.0',
#  '4500.0',
#  '1200.0',
#  '1000000.0',
#  '1000000.0',
#  '540.0',
#  '30.0',
#  '830.0',
#  '20000.0',
#  '1000000.0',
#  '1000000.0',
#  '390.0',
#  '390.0',
#  '430.0',
#  '1000000.0',
#  '600.0',
#  '2000.0',
#  '1000000.0',
#  '21000.0',
#  '290.0',
#  '700.0',
#  '460000.0',
#  '630.0',
#  '2100.0',
#  '330000.0',
#  '340000.0',
#  '1000000.0',
#  '290.0',
#  '210000.0',
#  '40.0',
#  '80.0',
#  '95.0',
#  '710000.0',
#  '180000.0',
#  '20000.0',
#  '60.0',
#  '70.0',
#  '280.0',
#  '11000.0',
#  '1500.0',
#  '650.0',
#  '930.0',
#  '370.0',
#  '4500.0',
#  '720000.0',
#  '30.0',
#  '7600.0',
#  '80.0',
#  '1000000.0',
#  '380.0',
#  '3300.0',
#  '1000000.0',
#  '370.0',
#  '9300.0',
#  '1000000.0',
#  '120.0',
#  '138038426460288.67',
#  '223872113856833.78',
#  '5888436553555884.0',
#  '154881661891248.6',
#  '70794578438414024',
#  '186208713666286.56',
#  '3235936569296281.0',
#  '1995262314968.88',
#  '4570881896148752.0',
#  '537031796370253.25',
#  '138038426460288.67',
#  '3000.0',
#  '10600.0',
#  '400.0',
#  '5.0',
#  '254.0',
#  '245000.0',
#  '366000.0',
#  '11480.0',
#  '6800.0',
#  '26500.0',
#  '2000.0',
#  '676.0',
#  '2980.0',
#  '18580.0',
#  '17900.0',
#  '4190.0',
#  '219.0',
#  '230.0',
#  '750.0',
#  '4.6',
#  '390.0',
#  '2570.0',
#  '40.0',
#  '670.0',
#  '110.0',
#  '280.0',
#  '160.0',
#  '230.0',
#  '19580.0',
#  '1000.0',
#  '53.0',
#  '1000.0',
#  '3170.0',
#  '520.0',
#  '2.6',
#  '120.0',
#  '110.0',
#  '3360.0',
#  '90.0',
#  '28.0',
#  '900.0',
#  '30.0',
#  '380.0',
#  '6.0',
#  '140.0',
#  '180.0',
#  '54.0',
#  '665.0',
#  '8.0',
#  '10000.0',
#  '160.0',
#  '9.0',
#  '3840.0',
#  '540.0',
#  '7.0',
#  '43.0',
#  '60.0',
#  '190.0',
#  '2670.0',
#  '4.5',
#  '5680.0',
#  '32.0',
#  '79.0',
#  '10.9',
#  '22.1',
#  '161.0',
#  '27.9',
#  '31.5',
#  '13.8',
#  '40.8',
#  '1090.0',
#  '68.9',
#  '61.0',
#  '2.33',
#  '21.0',
#  '9.4',
#  '9890.0',
#  '330.0',
#  '56.7',
#  '164.0',
#  '4.5',
#  '1.8',
#  '84.3',
#  '24.0',
#  '3500.0',
#  '33.5',
#  '231.0',
#  '1490.0',
#  '41130.0',
#  '3560.0',
#  '42.2',
#  '743.0',
#  '1100.0',
#  '710.0',
#  '143.0',
#  '3680.0',
#  '39.0',
#  '455.0',
#  '615.0',
#  '140.0',
#  '120.0',
#  '335.0',
#  '42.0',
#  '95.0',
#  '190.0',
#  '360.0',
#  '99.0',
#  '74.0',
#  '9810.0',
#  '78.0',
#  '429.0',
#  '658.0',
#  '470.0',
#  '6262.0',
#  '2600.0',
#  '606.0',
#  '266.0',
#  '39.0',
#  '66.0',
#  '190.0',
#  '16.0',
#  '313.0',
#  '1120.0',
#  '150.0',
#  '10000.0',
#  '10000.0',
#  '2.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '3000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '1300.0',
#  '3000.0',
#  '10000.0',
#  '10000.0',
#  '1000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '1040.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '1850.0',
#  '10000.0',
#  '330.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '3960.0',
#  '10000.0',
#  '1000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '10000.0',
#  '100000.0',
#  '23.0',
#  '21.0',
#  '31.0',
#  '35.0',
#  '150.0',
#  '220.0',
#  '230.0',
#  '350.0',
#  '15.0',
#  '16.0',
#  '22000.0',
#  '25000.0',
#  '100000.0',
#  '190.0',
#  '330.0',
#  '32.0',
#  '45.0',
#  '32000.0',
#  '23000.0',
#  '310.0',
#  '210.0',
#  '36.0',
#  '21.0',
#  '70000.0',
#  '30000.0',
#  '18000.0',
#  '20000.0',
#  '6000.0',
#  '25000.0',
#  '50000.0',
#  '50000.0',
#  '3300.0',
#  '1.5',
#  '6000.0',
#  '60000.0',
#  '80000.0',
#  '30000.0',
#  '94.0',
#  '11000.0',
#  '40.0',
#  '220.0',
#  '5.3',
#  '4400.0',
#  '0.82',
#  '5.3',
#  '11000.0',
#  '30000.0',
#  '10000.0',
#  '70000.0',
#  '3.0',
#  '160.0',
#  '30000.0',
#  '10.0',
#  '8.9',
#  '480.0',
#  '180.0',
#  '7.7',
#  '600.0',
#  '8000.0',
#  '1200.0',
#  '2900.0',
#  '0.9',
#  '4.2',
#  '8.4',
#  '180.0',
#  '6000.0',
#  '100000.0',
#  '219.79',
#  '930.0',
#  '140.0',
#  '0.7998',
#  '1500.0',
#  '319.89',
#  '15.0',
#  '785.0',
#  '50.0',
#  '9.397',
#  '20.0',
#  '54.95',
#  '10.0',
#  '14.0',
#  '16.0',
#  '78.0',
#  '209.89',
#  '340.41',
#  '8.299',
#  '18.97',
#  '28.0',
#  '8.79',
#  '7.998',
#  '28.0',
#  '47000.0',
#  '23.0',
#  '690.0',
#  '7.096',
#  '10000.0',
#  '26.0',
#  '7.194',
#  '26.0',
#  '269.77',
#  '14.0',
#  '1300.0',
#  '119.95',
#  '31.0',
#  '2582.26',
#  '22.0',
#  '260.0',
#  '2500.0',
#  '7.798',
#  '760.0',
#  '97.72',
#  '10.0',
#  '210.0',
#  '95.0',
#  '100.93',
#  '2.799',
#  '5.794',
#  '140.0',
#  '128.0',
#  '20.0',
#  '233.0',
#  '152.0',
#  '35000.0',
#  '40000.0',
#  '6300.0',
#  '91.0',
#  '460.0',
#  '34.0',
#  '76.0',
#  '1800.0',
#  '350.0',
#  '970.0',
#  '780.0',
#  '57.0',
#  '110.0',
#  '8.0',
#  '1700.0',
#  '11.7',
#  '12.4',
#  '27.4',
#  '0.3',
#  '5.4',
#  '1.4',
#  '82.6',
#  '29.3',
#  '6.8',
#  '21.1',
#  '14.1',
#  '24.7',
#  '0.32',
#  '54.6',
#  '26.2',
#  '79.6',
#  '210.0',
#  '21.8',
#  '5370.32',
#  '40.8',
#  '387.5',
#  '56.23',
#  '19.5',
#  '8.128',
#  '245.3',
#  '5754.4',
#  '11223.0',
#  '2847.5',
#  '7244.36',
#  '18.2',
#  '12.3',
#  '12.59',
#  '12.88',
#  '12.3',
#  '72.44',
#  '17.78',
#  '160.8',
#  '676.08',
#  '11.75',
#  '794.33',
#  '32.36',
#  '79.43',
#  '794.33',
#  '27.9',
#  '37.15',
#  '17.38',
#  '16.6',
#  '251.19',
#  '33.88',
#  '3500.5',
#  '9887.0',
#  '780.4',
#  '4570.88',
#  '18.62',
#  '16.22',
#  '17.38',
#  '18.62',
#  '204.17',
#  '24.0',
#  '48.98',
#  '2193.5',
#  '112.2',
#  '77.62',
#  '169.82',
#  '12.02',
#  '10.96',
#  '10.96',
#  '12.02',
#  '56.7',
#  '5654.5',
#  '6606.93',
#  '169.82',
#  '13.0',
#  '13.18',
#  '35000.0',
#  '0.48',
#  '4265.8',
#  '1819.7',
#  '8100.0',
#  '8128.31',
#  '5200.0',
#  '5128.61',
#  '28840.32',
#  '3000.0',
#  '3019.95',
#  '5888.44',
#  '45.0',
#  '45.71',
#  '16218.1',
#  '0.33',
#  '250.0',
#  '100.0',
#  '100.0',
#  '130.0',
#  '128.82',
#  '290.0',
#  '295.12',
#  '22.91',
#  '93000.0',
#  '39810.72',
#  '101000.0',
#  '436.52',
#  '390.0',
#  '389.05',
#  '17.78',
#  '26.0',
#  '550.0',
#  '549.54',
#  '80000.0',
#  '2.8',
#  '3700.0',
#  '3715.35',
#  '0.95',
#  '4570.88',
#  '350.0',
#  '354.81',
#  '9772.37',
#  '0.57',
#  '19.0',
#  '3890.45',
#  '67608.3',
#  '1.0',
#  '8.0',
#  '3.6',
#  '87.0',
#  '87.1',
#  '676.08',
#  '58000.0',
#  '3800.0',
#  '3801.89',
#  '6456.54',
#  '28.0',
#  '28.18',
#  '74.13',
#  '1949.84',
#  '7900.0',
#  '29.51',
#  '170.0',
#  '1659.59',
#  '460.0',
#  '467.74',
#  '9.0',
#  '10.0',
#  '66.0',
#  '70000.0',
#  '5370.32',
#  '170.0',
#  '169.82',
#  '1202.26',
#  '470.0',
#  '478.63',
#  '1600.0',
#  '1584.89',
#  '99000.0',
#  '750.0',
#  '741.31',
#  '4800.0',
#  '4786.3',
#  '100000.0',
#  '47.0',
#  '8.0',
#  '100000.0',
#  '100000.0',
#  '100000.0',
#  '100000.0',
#  '760.0',
#  '11900.0',
#  '62500.0',
#  '10000.0',
#  '144000.0',
#  '800.0',
#  '27000.0',
#  '175000.0',
#  '8500.0',
#  '28.0',
#  '96500.0',
#  '21800.0',
#  '339000.0',
#  '20300.0',
#  '185000.0',
#  '14500.0',
#  '47.0',
#  '4150.0',
#  '12700.0',
#  '76800.0',
#  '27900.0',
#  '175.0',
#  '10000.0',
#  '8720.0',
#  '366000.0',
#  '150.0',
#  '180.0',
#  '24200.0',
#  '125.0',
#  '10.0',
#  '100.0',
#  '7810.0',
#  '61500.0',
#  '5210.0',
#  '24.0',
#  '10.0',
#  '65.0',
#  '22.0',
#  '76600.0',
#  '8270.0',
#  '22.0',
#  '305000.0',
#  '24200.0',
#  '130.0',
#  '190.0',
#  '200.0',
#  '5.8',
#  '8.0',
#  '55.0',
#  '7.1',
#  '0.8',
#  '19.0',
#  '14.0',
#  '120.0',
#  '7.8',
#  '8.3',
#  '210.0',
#  '270.0',
#  '340.0',
#  '50.0',
#  '99.0',
#  '900.0',
#  '810.0',
#  '8.8',
#  '220.0',
#  '320.0',
#  '26.0',
#  '20.0',
#  '9.4',
#  '101.0',
#  '2.8',
#  '7.2',
#  '2600.0',
#  '62.0',
#  '20.0',
#  '36.0',
#  '58.0',
#  '154.0',
#  '506.0',
#  '12487.0',
#  '629.0',
#  '233.0',
#  '77.0',
#  '114.0',
#  '1330.0',
#  '253.0',
#  '518.0',
#  '211.0',
#  '69.0',
#  '1076.0',
#  '381.0',
#  '45.0',
#  '10000.0',
#  '546.0',
#  '176.0',
#  '90.0',
#  '93.0',
#  '110.0',
#  '208.0',
#  '38.0',
#  '2192.0',
#  '128.0',
#  '78.0',
#  '75.0',
#  '702.0',
#  '954.0',
#  '623.0',
#  '759.0',
#  '1610.0',
#  '2300.0',
#  '521.0',
#  '476.0',
#  '1412.54',
#  '104712.85',
#  '5370.32',
#  '15848.93',
#  '3388.44',
#  '169.82',
#  '33113.11',
#  '53703.18',
#  '6165.95',
#  '26000.0',
#  '4900.0',
#  '9.55',
#  '5333.35',
#  '7.998',
#  '49000.0',
#  '4900.0',
#  '10.0',
#  '4900.0',
#  '39.81',
#  '3767.04',
#  '345143.74',
#  '460.26',
#  '659.17',
#  '134000.0',
#  '38000.0',
#  '90.99',
#  '380.0',
#  '25.12',
#  '4900.0',
#  '1.995',
#  '1129795.91',
#  '380.0',
#  '81.28',
#  '39994.47',
#  '125892.54',
#  '349.95',
#  '380.0',
#  '8.913',
#  '57.02',
#  '152.05',
#  '32500.0',
#  '198000.0',
#  '439541.62',
#  '4900.0',
#  '3981.07',
#  '2824.88',
#  '122461.62',
#  '33.96',
#  '9500.0',
#  '56000.0',
#  '380.0',
#  '7.079',
#  '11587773.56',
#  '7800.0',
#  '4900.0',
#  '1.0',
#  '2387811.28',
#  '4900.0',
#  '36.31',
#  '4900.0',
#  '4897.79',
#  '470977.33',
#  '5970.35',
#  '76.03',
#  '366000.0',
#  '52.0',
#  '34994.52',
#  '21200.0',
#  '380.0',
#  '1.318',
#  '4900.0',
#  '3630.78',
#  '847227.41',
#  '6295.06',
#  '380.0',
#  '22.91',
#  '380.0',
#  '147.91',
#  '4900.0',
#  '9.55',
#  '2070141.35',
#  '816582.37',
#  '1000000.0',
#  '69023.98',
#  '339600.0',
#  '380.0',
#  '12.02',
#  '380.0',
#  '87.1',
#  '67000.0',
#  '84722.74',
#  '534564.36',
#  '40831.94',
#  '753355.56',
#  '27500.0',
#  '380.0',
#  '380.19',
#  '1729816.36',
#  '1158777.36',
#  '229086.77',
#  '238781.13',
#  '109.9',
#  '42000.0',
#  '380.0',
#  '36.31',
#  '4900.0',
#  '5.248',
#  '4900.0',
#  '100.0',
#  '3800.0',
#  '380.0',
#  '199.53',
#  '4900.0',
#  '1.82',
#  '3013006.02',
#  '1510080.15',
#  '597035.29',
#  '141253.75',
#  '779.83',
#  '4900.0',
#  '45.71',
#  '3706807.22',
#  '970.51',
#  '11500.0',
#  '123000.0',
#  '2917427.01',
#  '3111.72',
#  '25000.0',
#  '56000.0',
#  '380.0',
#  '13.18',
#  '1761976.05',
#  '0.43',
#  '5116818.36',
#  '597035.29',
#  '8400.0',
#  '380.0',
#  '5.248',
#  '8128305.16',
#  '3828247.43',
#  '3013.01',
#  '89000.0',
#  '972.75',
#  '33000.0',
#  '4900.0',
#  '218.78',
#  '690239.8',
#  '380.0',
#  '6.31',
#  '380.0',
#  '69.18',
#  '4900.0',
#  '3.981',
#  '87902.25',
#  '628058.36',
#  '191866.87',
#  '1698.24',
#  '24000.0',
#  '380.0',
#  '19.95',
#  '1798.87',
#  '200.0',
#  '500.0',
#  '1000000.0',
#  '10000000.0',
#  '10000000.0',
#  '500000.0',
#  '50000.0',
#  '1000000.0',
#  '1000000.0',
#  '30000.0',
#  '50000.0',
#  '50000.0',
#  '324.0',
#  '10.3',
#  '80000.0',
#  '100000.0',
#  '13000.0',
#  '360000.0',
#  '500000.0',
#  '1000000.0',
#  '1000000.0',
#  '50000.0',
#  '1000000.0',
#  '1000000.0',
#  '260000.0',
#  '110.0',
#  '90000.0',
#  '1000000.0',
#  '1000.0',
#  '1000000.0',
#  '1000000.0',
#  '1000000.0',
#  '758.0',
#  '1000000.0',
#  '6000.0',
#  '1000000.0',
#  '40.0',
#  '1760.0',
#  '40000.0',
#  '17.0',
#  '285.0',
#  '50000.0',
#  '500000.0',
#  '30000.0',
#  '100.0',
#  '2020.0',
#  '800.0',
#  '50000.0',
#  '390000.0',
#  '30000.0',
#  '550.0',
#  '1000000.0',
#  '24.0',
#  '5000000.0',
#  '1000000.0',
#  '1000000.0',
#  '1000.0',
#  '1000.0',
#  '3660.0',
#  '500.0',
#  '2.11',
#  '0.75',
#  '100.0',
#  '106.0',
#  '436.0',
#  '1500.0',
#  '30.0',
#  '1.39',
#  '205.0',
#  '1260.0',
#  '51.6',
#  '100000.0',
#  '9200.0',
#  '0.78',
#  '29.5',
#  '425.0',
#  '2.2',
#  '1700.0',
#  '205.0',
#  '37.8',
#  '23.1',
#  '3720.0',
#  '35.4',
#  '125.0',
#  '4.96',
#  '0.32',
#  '260.0',
#  '4.58',
#  '76.9',
#  '260.0',
#  '158.0',
#  '13510.0',
#  '100000.0',
#  '11.7',
#  '1.76',
#  '3.79',
#  '290000.0',
#  '0.32',
#  '150.0',
#  '3760.0',
#  '123.0',
#  '30.0',
#  '22.0',
#  '680.0',
#  '240.0',
#  '33.0',
#  '8.0',
#  '1200.0',
#  '440.0',
#  '43.0',
#  '2100.0',
#  '650.0',
#  '50.0',
#  '310.0',
#  '17.0',
#  '66.0',
#  '44.5',
#  '120.0',
#  '83.0',
#  '23.1',
#  '120.0',
#  '76.0',
#  '18.0',
#  '260.0',
#  '650.0',
#  '18.9',
#  '160.0',
#  '500.0',
#  '500.0',
#  '6.8',
#  '500.0',
#  '630.0',
#  '30.0',
#  '4.3',
#  '520.0',
#  '305.0',
#  '370.0',
#  '470.0',
#  '690.0',
#  '270.0',
#  '500.0',
#  '25.0',
#  '180.0',
#  '1300.0',
#  '12.0',
#  '8.0',
#  '100.0',
#  '267.0',
#  '200.0',
#  '139.0',
#  '640.0',
#  '100000.0',
#  ...]

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3_alt = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3_alt
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 6337      CHEMBL4645659  ...          740.0
# 6338       CHEMBL513063  ...          510.0
# 6339      CHEMBL4640608  ...       125000.0
# 6340      CHEMBL4173961  ...       100000.0
# 6341           CHEMBL95  ...          100.0
#
# [6342 rows x 4 columns]

# %% [markdown]
# ### **Alternative Method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7544      CHEMBL4645659  ...          740.0
# 7545       CHEMBL513063  ...          510.0
# 7546      CHEMBL4640608  ...       125000.0
# 7547      CHEMBL4173961  ...       100000.0
# 7548           CHEMBL95  ...          100.0
#
# [6342 rows x 3 columns]

# %%
pd.concat([df3, pd.Series(bioactivity_class)], axis = 1)
# Out:
#      molecule_chembl_id  ...         0
# 0          CHEMBL133897  ...    active
# 1          CHEMBL336398  ...    active
# 2          CHEMBL131588  ...  inactive
# 3          CHEMBL130628  ...    active
# 4          CHEMBL130478  ...    active
# ...                 ...  ...       ...
# 7544      CHEMBL4645659  ...       NaN
# 7545       CHEMBL513063  ...       NaN
# 7546      CHEMBL4640608  ...       NaN
# 7547      CHEMBL4173961  ...       NaN
# 7548           CHEMBL95  ...       NaN
#
# [7479 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('AChE_bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 4232
# -rw-r--r-- 1 root root 3870914 Aug  2 09:31 AChE_bioactivity_data.csv
# -rw-r--r-- 1 root root  450457 Aug  2 09:39 AChE_bioactivity_preprocessed_data.csv
# drwx------ 5 root root    4096 Aug  2 09:31 gdrive
# drwxr-xr-x 1 root root    4096 Jul 16 13:20 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp AChE_bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/Data Collection and Pre-processing/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/Data Collection and Pre-processing/data"
# Out:
# AChE_bioactivity_data.csv		bioactivity_data.csv
# AChE_bioactivity_preprocessed_data.csv	bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
