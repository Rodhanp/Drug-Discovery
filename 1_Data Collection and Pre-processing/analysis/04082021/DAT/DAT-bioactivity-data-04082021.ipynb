# %% [markdown]
# # **Computational Drug Discovery Pipelines-**
# ## **Data Collection and Pre-processing**

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in d:\anaconda\envs\work\lib\site-packages (0.10.7)
# Requirement already satisfied: urllib3 in d:\anaconda\envs\work\lib\site-packages (from chembl_webresource_client) (1.26.6)
# WARNING: Ignoring invalid distribution -tkinter-pymol (d:\anaconda\envs\work\dlls)
# WARNING: Ignoring invalid distribution -tkinter-pymol (d:\anaconda\envs\work\dlls)
# WARNING: Ignoring invalid distribution -tkinter-pymol (d:\anaconda\envs\work\dlls)
# WARNING: Ignoring invalid distribution -tkinter-pymol (d:\anaconda\envs\work\dlls)
# WARNING: Ignoring invalid distribution -tkinter-pymol (d:\anaconda\envs\work\dlls)
# WARNING: Ignoring invalid distribution -tkinter-pymol (d:\anaconda\envs\work\dlls)
# Requirement already satisfied: easydict in d:\anaconda\envs\work\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: requests>=2.18.4 in d:\anaconda\envs\work\lib\site-packages (from chembl_webresource_client) (2.25.1)
# Requirement already satisfied: requests-cache~=0.7.0 in d:\anaconda\envs\work\lib\site-packages (from chembl_webresource_client) (0.7.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda\envs\work\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\work\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\envs\work\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: attrs<22.0,>=21.2 in d:\anaconda\envs\work\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in d:\anaconda\envs\work\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: itsdangerous>=2.0.1 in d:\anaconda\envs\work\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: pyyaml>=5.4 in d:\anaconda\envs\work\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (5.4.1)
# Requirement already satisfied: six in d:\anaconda\envs\work\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.14.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for GABA**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Dopamine active transporter')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references             organism  \
# 0    [{'xref_id': 'Q01959', 'xref_name': None, 'xre...         Homo sapiens
# 1    [{'xref_id': 'Q61327', 'xref_name': None, 'xre...         Mus musculus
# 2    [{'xref_id': 'P23977', 'xref_name': None, 'xre...    Rattus norvegicus
# 3    [{'xref_id': 'P27922', 'xref_name': None, 'xre...           Bos taurus
# 4    [{'xref_id': 'Q9GJT6', 'xref_name': None, 'xre...  Macaca fascicularis
# ..                                                 ...                  ...
# 930                                                 []    Rattus norvegicus
# 931                                                 []         Homo sapiens
# 932                                                 []         Homo sapiens
# 933                                                 []         Homo sapiens
# 934                                                 []         Homo sapiens
#
#                          pref_name  score  species_group_flag  \
# 0             Dopamine transporter   19.0               False
# 1             Dopamine transporter   19.0               False
# 2             Dopamine transporter   19.0               False
# 3             Dopamine transporter   19.0               False
# 4             Dopamine transporter   19.0               False
# ..                             ...    ...                 ...
# 930              Adenylate cyclase    0.0               False
# 931  Voltage-gated calcium channel    0.0               False
# 932              Retinoid receptor    0.0               False
# 933        Cyclin-dependent kinase    0.0               False
# 934                        Caspase    0.0               False
#
#     target_chembl_id                                  target_components  \
# 0          CHEMBL238  [{'accession': 'Q01959', 'component_descriptio...
# 1         CHEMBL2799  [{'accession': 'Q61327', 'component_descriptio...
# 2          CHEMBL338  [{'accession': 'P23977', 'component_descriptio...
# 3         CHEMBL2986  [{'accession': 'P27922', 'component_descriptio...
# 4         CHEMBL5032  [{'accession': 'Q9GJT6', 'component_descriptio...
# ..               ...                                                ...
# 930    CHEMBL2095179  [{'accession': 'D4A3N4', 'component_descriptio...
# 931    CHEMBL2363032  [{'accession': 'O95180', 'component_descriptio...
# 932    CHEMBL2363071  [{'accession': 'P28702', 'component_descriptio...
# 933    CHEMBL3559691  [{'accession': 'P06493', 'component_descriptio...
# 934    CHEMBL3831289  [{'accession': 'P49662', 'component_descriptio...
#
#                target_type   tax_id
# 0           SINGLE PROTEIN   9606.0
# 1           SINGLE PROTEIN  10090.0
# 2           SINGLE PROTEIN  10116.0
# 3           SINGLE PROTEIN   9913.0
# 4           SINGLE PROTEIN   9541.0
# ..                     ...      ...
# 930         PROTEIN FAMILY  10116.0
# 931  PROTEIN COMPLEX GROUP   9606.0
# 932         PROTEIN FAMILY   9606.0
# 933         PROTEIN FAMILY   9606.0
# 934         PROTEIN FAMILY   9606.0
#
# [935 rows x 9 columns]

# %%
targets.to_csv('DAT_targets_search_results.csv')

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Dopamine transporter* (zeroth entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *Dopamine transporter* to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL238'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Dopamine transporter* (CHEMBL238) that are reported as IC50 values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        53425                  []    CHEMBL671771
# 1                None        70053                  []    CHEMBL671771
# 2                None        71269                  []    CHEMBL671771
# 3                None        75844                  []    CHEMBL871936
# 4                None        75845                  []    CHEMBL674122
# ...               ...          ...                 ...             ...
# 3363           Active     20723981                  []   CHEMBL4510296
# 3364             None     20745381                  []   CHEMBL4508895
# 3365             None     20753778                  []   CHEMBL4508895
# 3366             None     20760434                  []   CHEMBL4508895
# 3367       Not Active     20771762                  []   CHEMBL4510304
#
#                                       assay_description assay_type  \
# 0     Inhibitory activity against [3H]-Dopamine upta...          B
# 1     Inhibitory activity against [3H]-Dopamine upta...          B
# 2     Inhibitory activity against [3H]-Dopamine upta...          B
# 3     Antagonism of cocaine''s inhibition of [3H]DA ...          F
# 4     Antagonism of cocaine''s inhibition of [3H]DA ...          F
# ...                                                 ...        ...
# 3363                              Dopamine-uptake assay          B
# 3364  Transporter, Dopamine (DAT) Eurofins-Panlabs r...          B
# 3365  Transporter, Dopamine (DAT) Eurofins-Panlabs r...          B
# 3366  Transporter, Dopamine (DAT) Eurofins-Panlabs r...          B
# 3367  Functional Assay: Platelet-rich plasma SLC6A3/...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000221
# 1                       None                   None  BAO_0000190  BAO_0000221
# 2                       None                   None  BAO_0000190  BAO_0000221
# 3                       None                   None  BAO_0000190  BAO_0000019
# 4                       None                   None  BAO_0000190  BAO_0000019
# ...                      ...                    ...          ...          ...
# 3363                    None                   None  BAO_0000190  BAO_0000357
# 3364                    None                   None  BAO_0000190  BAO_0000357
# 3365                    None                   None  BAO_0000190  BAO_0000357
# 3366                    None                   None  BAO_0000190  BAO_0000357
# 3367                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Dopamine transporter          9606       None
# 1     ...    Homo sapiens  Dopamine transporter          9606       None
# 2     ...    Homo sapiens  Dopamine transporter          9606       None
# 3     ...    Homo sapiens  Dopamine transporter          9606       None
# 4     ...    Homo sapiens  Dopamine transporter          9606       None
# ...   ...             ...                   ...           ...        ...
# 3363  ...    Homo sapiens  Dopamine transporter          9606       None
# 3364  ...    Homo sapiens  Dopamine transporter          9606       None
# 3365  ...    Homo sapiens  Dopamine transporter          9606       None
# 3366  ...    Homo sapiens  Dopamine transporter          9606       None
# 3367  ...    Homo sapiens  Dopamine transporter          9606       None
#
#       toid  type  units    uo_units upper_value   value
# 0     None  IC50     nM  UO_0000065        None   373.0
# 1     None  IC50     nM  UO_0000065        None   405.0
# 2     None  IC50     nM  UO_0000065        None  3890.0
# 3     None  IC50     nM  UO_0000065        None   470.0
# 4     None  IC50     nM  UO_0000065        None   717.0
# ...    ...   ...    ...         ...         ...     ...
# 3363  None  IC50     nM  UO_0000065        None   536.0
# 3364  None  IC50     µM        None        None     1.2
# 3365  None  IC50     µM        None        None    2.31
# 3366  None  IC50     µM        None        None    2.17
# 3367  None  IC50     nM  UO_0000065        None  8692.0
#
# [3368 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('DAT-bioactivity_data_04082021.csv', index=False)

# %% [markdown]
# ## **For copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
#from google.colab import drive
#drive.mount('/content/gdrive/', force_remount=True)

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
#! mkdir "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/data"

# %%
#! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/data"

# %%
#! ls -l "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/data"

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
#! ls

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! DAT-bioactivity_data_04082021.csv

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df.shape
# Out:
# (3368, 45)

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        53425                  []    CHEMBL671771
# 1                None        70053                  []    CHEMBL671771
# 2                None        71269                  []    CHEMBL671771
# 3                None        75844                  []    CHEMBL871936
# 4                None        75845                  []    CHEMBL674122
# ...               ...          ...                 ...             ...
# 3363           Active     20723981                  []   CHEMBL4510296
# 3364             None     20745381                  []   CHEMBL4508895
# 3365             None     20753778                  []   CHEMBL4508895
# 3366             None     20760434                  []   CHEMBL4508895
# 3367       Not Active     20771762                  []   CHEMBL4510304
#
#                                       assay_description assay_type  \
# 0     Inhibitory activity against [3H]-Dopamine upta...          B
# 1     Inhibitory activity against [3H]-Dopamine upta...          B
# 2     Inhibitory activity against [3H]-Dopamine upta...          B
# 3     Antagonism of cocaine''s inhibition of [3H]DA ...          F
# 4     Antagonism of cocaine''s inhibition of [3H]DA ...          F
# ...                                                 ...        ...
# 3363                              Dopamine-uptake assay          B
# 3364  Transporter, Dopamine (DAT) Eurofins-Panlabs r...          B
# 3365  Transporter, Dopamine (DAT) Eurofins-Panlabs r...          B
# 3366  Transporter, Dopamine (DAT) Eurofins-Panlabs r...          B
# 3367  Functional Assay: Platelet-rich plasma SLC6A3/...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000221
# 1                       None                   None  BAO_0000190  BAO_0000221
# 2                       None                   None  BAO_0000190  BAO_0000221
# 3                       None                   None  BAO_0000190  BAO_0000019
# 4                       None                   None  BAO_0000190  BAO_0000019
# ...                      ...                    ...          ...          ...
# 3363                    None                   None  BAO_0000190  BAO_0000357
# 3364                    None                   None  BAO_0000190  BAO_0000357
# 3365                    None                   None  BAO_0000190  BAO_0000357
# 3366                    None                   None  BAO_0000190  BAO_0000357
# 3367                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Dopamine transporter          9606       None
# 1     ...    Homo sapiens  Dopamine transporter          9606       None
# 2     ...    Homo sapiens  Dopamine transporter          9606       None
# 3     ...    Homo sapiens  Dopamine transporter          9606       None
# 4     ...    Homo sapiens  Dopamine transporter          9606       None
# ...   ...             ...                   ...           ...        ...
# 3363  ...    Homo sapiens  Dopamine transporter          9606       None
# 3364  ...    Homo sapiens  Dopamine transporter          9606       None
# 3365  ...    Homo sapiens  Dopamine transporter          9606       None
# 3366  ...    Homo sapiens  Dopamine transporter          9606       None
# 3367  ...    Homo sapiens  Dopamine transporter          9606       None
#
#       toid  type  units    uo_units upper_value   value
# 0     None  IC50     nM  UO_0000065        None   373.0
# 1     None  IC50     nM  UO_0000065        None   405.0
# 2     None  IC50     nM  UO_0000065        None  3890.0
# 3     None  IC50     nM  UO_0000065        None   470.0
# 4     None  IC50     nM  UO_0000065        None   717.0
# ...    ...   ...    ...         ...         ...     ...
# 3363  None  IC50     nM  UO_0000065        None   536.0
# 3364  None  IC50     µM        None        None     1.2
# 3365  None  IC50     µM        None        None    2.31
# 3366  None  IC50     µM        None        None    2.17
# 3367  None  IC50     nM  UO_0000065        None  8692.0
#
# [2451 rows x 45 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL1790051
# 1        CHEMBL370805
# 2        CHEMBL611999
# 3        CHEMBL120633
# 4        CHEMBL120633
#             ...
# 3363    CHEMBL3609637
# 3364    CHEMBL4514203
# 3365    CHEMBL1800685
# 3366    CHEMBL4521594
# 3367     CHEMBL561132
# Name: molecule_chembl_id, Length: 2451, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
#mol_cid

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
#canonical_smiles

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
#standard_value

# %% [markdown]
# ### **Combine the 3 columns into a dataframe**

# %%
#data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
#df3_alt = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
#df3_alt

# %% [markdown]
# ### **Alternative Method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1790051    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccccc1)N2C.Cl
# 1          CHEMBL370805  COC(=O)[C@H]1[C@@H](OC(=O)c2ccccc2)C[C@@H]2CC[...
# 2          CHEMBL611999                                               None
# 3          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# 4          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# ...                 ...                                                ...
# 3363      CHEMBL3609637  COc1cc(-c2cn(C3CCc4c(F)cccc4N(CC(F)(F)F)C3=O)n...
# 3364      CHEMBL4514203             O[C@]1(C(F)(F)F)CCCC[C@H]1Nc1ccc(F)cc1
# 3365      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 3366      CHEMBL4521594   NS(=O)(=O)c1cc(NC(=O)Cc2ccccc2)ccc1Oc1cccc(Cl)c1
# 3367       CHEMBL561132  CN([C@@H]1CCc2c(CC(=O)O)c3ccccc3n2C1)S(=O)(=O)...
#
#      standard_value
# 0             373.0
# 1             405.0
# 2            3890.0
# 3             470.0
# 4             717.0
# ...             ...
# 3363          536.0
# 3364            1.2
# 3365           2.31
# 3366           2.17
# 3367         8692.0
#
# [2451 rows x 3 columns]

# %%
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1790051    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccccc1)N2C.Cl
# 1          CHEMBL370805  COC(=O)[C@H]1[C@@H](OC(=O)c2ccccc2)C[C@@H]2CC[...
# 3          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# 4          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# 5          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# ...                 ...                                                ...
# 3363      CHEMBL3609637  COc1cc(-c2cn(C3CCc4c(F)cccc4N(CC(F)(F)F)C3=O)n...
# 3364      CHEMBL4514203             O[C@]1(C(F)(F)F)CCCC[C@H]1Nc1ccc(F)cc1
# 3365      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 3366      CHEMBL4521594   NS(=O)(=O)c1cc(NC(=O)Cc2ccccc2)ccc1Oc1cccc(Cl)c1
# 3367       CHEMBL561132  CN([C@@H]1CCc2c(CC(=O)O)c3ccccc3n2C1)S(=O)(=O)...
#
#      standard_value
# 0             373.0
# 1             405.0
# 3             470.0
# 4             717.0
# 5            1161.0
# ...             ...
# 3363          536.0
# 3364            1.2
# 3365           2.31
# 3366           2.17
# 3367         8692.0
#
# [2425 rows x 3 columns]

# %%
bioactivity_class= pd.Series(bioactivity_class, name = 'bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis = 1)
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1790051    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccccc1)N2C.Cl
# 1          CHEMBL370805  COC(=O)[C@H]1[C@@H](OC(=O)c2ccccc2)C[C@@H]2CC[...
# 2          CHEMBL611999                                               None
# 3          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# 4          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# ...                 ...                                                ...
# 3363      CHEMBL3609637  COc1cc(-c2cn(C3CCc4c(F)cccc4N(CC(F)(F)F)C3=O)n...
# 3364      CHEMBL4514203             O[C@]1(C(F)(F)F)CCCC[C@H]1Nc1ccc(F)cc1
# 3365      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 3366      CHEMBL4521594   NS(=O)(=O)c1cc(NC(=O)Cc2ccccc2)ccc1Oc1cccc(Cl)c1
# 3367       CHEMBL561132  CN([C@@H]1CCc2c(CC(=O)O)c3ccccc3n2C1)S(=O)(=O)...
#
#      standard_value bioactivity_class
# 0             373.0            active
# 1             405.0            active
# 2            3890.0      intermediate
# 3             470.0            active
# 4             717.0            active
# ...             ...               ...
# 3363          536.0               NaN
# 3364            1.2               NaN
# 3365           2.31               NaN
# 3366           2.17               NaN
# 3367         8692.0               NaN
#
# [3126 rows x 4 columns]

# %%
df5=df4.dropna()
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1790051    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccccc1)N2C.Cl
# 1          CHEMBL370805  COC(=O)[C@H]1[C@@H](OC(=O)c2ccccc2)C[C@@H]2CC[...
# 3          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# 4          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# 5          CHEMBL120633  COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C...
# ...                 ...                                                ...
# 2413           CHEMBL91        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# 2414         CHEMBL1373               NC(=O)C[S+]([O-])C(c1ccccc1)c1ccccc1
# 2419        CHEMBL19215  CN1C[C@H](CNC(=O)OCc2ccccc2)C[C@@H]2c3cccc4c3c...
# 2424      CHEMBL1200633  CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@...
# 2446          CHEMBL787  CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cc...
#
#      standard_value bioactivity_class
# 0             373.0            active
# 1             405.0            active
# 3             470.0            active
# 4             717.0            active
# 5            1161.0      intermediate
# ...             ...               ...
# 2413         1701.0          inactive
# 2414         1832.0      intermediate
# 2419           63.0          inactive
# 2424         4455.2      intermediate
# 2446         2601.0            active
#
# [1750 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('DAT-bioactivity_preprocessed_data_04082021.csv', index=False)

# %%
#! ls -l

# %% [markdown]
# For copying to the Google Drive

# %%
#! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/data"

# %%
#! ls "/content/gdrive/My Drive/Colab Notebooks/Bioinformatics Project/Drug Discovery/data"

# %% [markdown]
# ---
