# %% [markdown]
# # **Descriptor Calculation and Dataset Preparation**
#
# Calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset.
# Finally, we will be preparing this into a dataset for subsequent model building
#
# ---

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/Rodhanp/Drug-Discovery/raw/main/3_Dataset%20Preparation/paDEL/padel.zip
! wget https://github.com/Rodhanp/Drug-Discovery/raw/main/3_Dataset%20Preparation/paDEL/padel.sh
# Out:
# --2021-08-04 22:48:28--  https://github.com/Rodhanp/Drug-Discovery/raw/main/3_Dataset%20Preparation/paDEL/padel.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/3_Dataset%20Preparation/paDEL/padel.zip [following]
# --2021-08-04 22:48:28--  https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/3_Dataset%20Preparation/paDEL/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2 of this Bioinformatics Project series. Here we will be using the **SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
! wget https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/2_Exploratory%20Data%20Analysis/output/DAT/DAT_bioactivity_data_3class_pIC50_04082021.csv
# Out:
# --2021-08-04 22:48:48--  https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/2_Exploratory%20Data%20Analysis/output/DAT/DAT_bioactivity_data_3class_pIC50_04082021.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219965 (215K) [text/plain]
# Saving to: ‘DAT_bioactivity_data_3class_pIC50_04082021.csv’
#
# DAT_bioactivity_dat 100%[===================>] 214.81K  --.-KB/s    in 0.002s
#
# 2021-08-04 22:48:48 (126 MB/s) - ‘DAT_bioactivity_data_3class_pIC50_04082021.csv’ saved [219965/219965]

# %%
import pandas as pd

# %%
df3 = pd.read_csv('DAT_bioactivity_data_3class_pIC50_04082021.csv')

# %%
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0      CHEMBL1790051  ...           3.0  6.428291
# 1              1       CHEMBL370805  ...           5.0  6.392545
# 2              2       CHEMBL120633  ...           8.0  6.327902
# 3              3       CHEMBL120633  ...           8.0  6.144481
# 4              4       CHEMBL120633  ...           8.0  5.935168
# ...          ...                ...  ...           ...       ...
# 1745        1745           CHEMBL91  ...           3.0  5.769296
# 1746        1746         CHEMBL1373  ...           2.0  5.737075
# 1747        1747        CHEMBL19215  ...           4.0  7.200659
# 1748        1748      CHEMBL1200633  ...          28.0  5.351133
# 1749        1749          CHEMBL787  ...           4.0  5.584860
#
# [1750 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccccc1)N2C.Cl	CHEMBL1790051
# COC(=O)[C@H]1[C@@H](OC(=O)c2ccccc2)C[C@@H]2CC[C@H]1N2C	CHEMBL370805
# COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C.Cc1ccc(C(=O)C2CN(C)CCC2(O)c2ccc(C)cc2)cc1	CHEMBL120633
# COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C.Cc1ccc(C(=O)C2CN(C)CCC2(O)c2ccc(C)cc2)cc1	CHEMBL120633
# COC(=O)[C@@H]1C2CCC(C[C@@H]1C(=O)Oc1ccccc1)N2C.Cc1ccc(C(=O)C2CN(C)CCC2(O)c2ccc(C)cc2)cc1	CHEMBL120633

# %%
! cat molecule.smi | wc -l
# Out:
# 1750

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL370805 in molecule.smi (2/1750).
# Processing CHEMBL1790051 in molecule.smi (1/1750).
# Processing CHEMBL120633 in molecule.smi (3/1750). Average speed: 2.90 s/mol.
# Processing CHEMBL120633 in molecule.smi (4/1750). Average speed: 1.52 s/mol.
# Processing CHEMBL120633 in molecule.smi (5/1750). Average speed: 1.27 s/mol.
# Processing CHEMBL435341 in molecule.smi (6/1750). Average speed: 1.00 s/mol.
# Processing CHEMBL173594 in molecule.smi (7/1750). Average speed: 0.97 s/mol.
# Processing CHEMBL28376 in molecule.smi (8/1750). Average speed: 0.87 s/mol.
# Processing CHEMBL28376 in molecule.smi (9/1750). Average speed: 0.83 s/mol.
# Processing CHEMBL28394 in molecule.smi (10/1750). Average speed: 0.75 s/mol.
# Processing CHEMBL28394 in molecule.smi (11/1750). Average speed: 0.73 s/mol.
# Processing CHEMBL27336 in molecule.smi (12/1750). Average speed: 0.67 s/mol.
# Processing CHEMBL27336 in molecule.smi (13/1750). Average speed: 0.65 s/mol.
# ...

# %%
! ls -l
# Out:
# total 28544
# -rw-r--r-- 1 root root   219965 Aug  4 22:48 DAT_bioactivity_data_3class_pIC50_04082021.csv
# -rw-r--r-- 1 root root  3121094 Aug  4 22:55 descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Aug  4 22:48 __MACOSX
# -rw-r--r-- 1 root root    97649 Aug  4 22:49 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Aug  4 22:48 padel.sh
# -rw-r--r-- 1 root root 25768637 Aug  4 22:48 padel.zip
# drwxr-xr-x 1 root root     4096 Jul 16 13:20 sample_data

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL370805           1  ...             0             0
# 1     CHEMBL1790051           1  ...             0             0
# 2      CHEMBL120633           1  ...             0             0
# 3      CHEMBL120633           1  ...             0             0
# 4      CHEMBL120633           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 1745    CHEMBL21731           1  ...             0             0
# 1746     CHEMBL1373           1  ...             0             0
# 1747    CHEMBL19215           1  ...             0             0
# 1748  CHEMBL1200633           1  ...             0             0
# 1749      CHEMBL787           1  ...             0             0
#
# [1750 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 1745           1           1  ...             0             0
# 1746           1           1  ...             0             0
# 1747           1           1  ...             0             0
# 1748           1           1  ...             0             0
# 1749           1           1  ...             0             0
#
# [1750 rows x 881 columns]

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       6.428291
# 1       6.392545
# 2       6.327902
# 3       6.144481
# 4       5.935168
#           ...
# 1745    5.769296
# 1746    5.737075
# 1747    7.200659
# 1748    5.351133
# 1749    5.584860
# Name: pIC50, Length: 1750, dtype: float64

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.428291
# 1              1           1           1  ...             0             0  6.392545
# 2              1           1           1  ...             0             0  6.327902
# 3              1           1           1  ...             0             0  6.144481
# 4              1           1           1  ...             0             0  5.935168
# ...          ...         ...         ...  ...           ...           ...       ...
# 1745           1           1           1  ...             0             0  5.769296
# 1746           1           1           0  ...             0             0  5.737075
# 1747           1           1           1  ...             0             0  7.200659
# 1748           1           1           1  ...             0             0  5.351133
# ...

# %%
dataset3.to_csv('DAT_bioactivity_data_3class_pIC50_pubchem_fp_04082021.csv', index=False)

# %% [markdown]
# # **Download the CSV file to computer for Model Building.**
