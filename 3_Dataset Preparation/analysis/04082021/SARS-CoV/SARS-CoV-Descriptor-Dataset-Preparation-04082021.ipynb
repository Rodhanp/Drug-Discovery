# %% [markdown]
# # **Descriptor Calculation and Dataset Preparation**
#
# Calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset.
# Finally, we will be preparing this into a dataset for subsequent model building
#
# ---

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/Rodhanp/Drug-Discovery/raw/main/3_Dataset%20Preparation/paDEL/padel.zip
! wget https://github.com/Rodhanp/Drug-Discovery/raw/main/3_Dataset%20Preparation/paDEL/padel.sh
# Out:
# --2021-08-04 09:37:58--  https://github.com/Rodhanp/Drug-Discovery/raw/main/3_Dataset%20Preparation/paDEL/padel.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/3_Dataset%20Preparation/paDEL/padel.zip [following]
# --2021-08-04 09:37:58--  https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/3_Dataset%20Preparation/paDEL/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip.3’
#
# padel.zip.3         100%[===================>]  24.57M  55.6MB/s    in 0.4s
#
# ...

# %%
! unzip padel.zip.3
# Out:
# Archive:  padel.zip.3
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2 of this Bioinformatics Project series. Here we will be using the **SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
! wget https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/2_Exploratory%20Data%20Analysis/output/CoV/04082021/SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv
# Out:
# --2021-08-04 09:38:41--  https://raw.githubusercontent.com/Rodhanp/Drug-Discovery/main/2_Exploratory%20Data%20Analysis/output/CoV/04082021/SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17210 (17K) [text/plain]
# Saving to: ‘SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv.3’
#
# SARS-CoV_bioactivit 100%[===================>]  16.81K  --.-KB/s    in 0.001s
#
# 2021-08-04 09:38:41 (25.8 MB/s) - ‘SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv.3’ saved [17210/17210]

# %%
import pandas as pd

# %%
df3 = pd.read_csv('SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv.3')

# %%
df3
# Out:
#      Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0             0       CHEMBL187579  ...           5.0  5.142668
# 1             1       CHEMBL188487  ...           2.0  5.026872
# 2             2       CHEMBL185698  ...           4.0  4.869666
# 3             3       CHEMBL426082  ...           3.0  4.882397
# 4             4       CHEMBL187717  ...           5.0  5.698970
# ..          ...                ...  ...           ...       ...
# 128         128      CHEMBL2146517  ...           5.0  4.974694
# 129         129       CHEMBL187460  ...           3.0  4.995679
# 130         130       CHEMBL363535  ...           3.0  4.939302
# 131         131       CHEMBL227075  ...           3.0  4.970616
# 132         132        CHEMBL45830  ...           2.0  4.102923
#
# [133 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21	CHEMBL187579
# O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21	CHEMBL188487
# O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21	CHEMBL185698
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21	CHEMBL426082
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]	CHEMBL187717

# %%
! cat molecule.smi | wc -l
# Out:
# 133

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat padel.sh.3
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh.3
# Out:
# Processing CHEMBL187579 in molecule.smi (1/133).
# Processing CHEMBL188487 in molecule.smi (2/133).
# Processing CHEMBL185698 in molecule.smi (3/133). Average speed: 2.11 s/mol.
# Processing CHEMBL426082 in molecule.smi (4/133). Average speed: 1.15 s/mol.
# Processing CHEMBL187717 in molecule.smi (5/133). Average speed: 0.97 s/mol.
# Processing CHEMBL365134 in molecule.smi (6/133). Average speed: 0.75 s/mol.
# Processing CHEMBL187598 in molecule.smi (7/133). Average speed: 0.73 s/mol.
# Processing CHEMBL190743 in molecule.smi (8/133). Average speed: 0.64 s/mol.
# Processing CHEMBL365469 in molecule.smi (9/133). Average speed: 0.63 s/mol.
# Processing CHEMBL188983 in molecule.smi (10/133). Average speed: 0.56 s/mol.
# Processing CHEMBL191575 in molecule.smi (11/133). Average speed: 0.54 s/mol.
# Processing CHEMBL370923 in molecule.smi (12/133). Average speed: 0.52 s/mol.
# Processing CHEMBL194398 in molecule.smi (13/133). Average speed: 0.49 s/mol.
# ...

# %%
! ls -l
# Out:
# total 51180
# -rw-r--r-- 1 root root   247688 Aug  4 09:40 descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Aug  4 09:38 __MACOSX
# -rw-r--r-- 1 root root     7991 Aug  4 09:38 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root   123375 Aug  4 09:32 padel.sh
# -rw-r--r-- 1 root root   123379 Aug  4 09:33 padel.sh.1
# -rw-r--r-- 1 root root      231 Aug  4 09:36 padel.sh.2
# -rw-r--r-- 1 root root      231 Aug  4 09:37 padel.sh.3
# -rw-r--r-- 1 root root   125088 Aug  4 09:32 padel.zip
# -rw-r--r-- 1 root root   120551 Aug  4 09:33 padel.zip.1
# -rw-r--r-- 1 root root 25768637 Aug  4 09:36 padel.zip.2
# -rw-r--r-- 1 root root 25768637 Aug  4 09:37 padel.zip.3
# drwxr-xr-x 1 root root     4096 Jul 16 13:20 sample_data
# -rw-r--r-- 1 root root    17210 Aug  4 09:32 SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv
# -rw-r--r-- 1 root root    17210 Aug  4 09:33 SARS-CoV_bioactivity_data_3class_pIC50_04082021.csv.1
# ...

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL187579           1  ...             0             0
# 1     CHEMBL188487           1  ...             0             0
# 2     CHEMBL185698           1  ...             0             0
# 3     CHEMBL426082           1  ...             0             0
# 4     CHEMBL187717           1  ...             0             0
# ..             ...         ...  ...           ...           ...
# 128   CHEMBL187460           1  ...             0             0
# 129  CHEMBL2146517           1  ...             0             0
# 130   CHEMBL227075           1  ...             0             0
# 131   CHEMBL363535           1  ...             0             0
# 132    CHEMBL45830           1  ...             0             0
#
# [133 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 128           1           1  ...             0             0
# 129           1           1  ...             0             0
# 130           1           1  ...             0             0
# 131           1           1  ...             0             0
# 132           1           1  ...             0             0
#
# [133 rows x 881 columns]

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0      5.142668
# 1      5.026872
# 2      4.869666
# 3      4.882397
# 4      5.698970
#          ...
# 128    4.974694
# 129    4.995679
# 130    4.939302
# 131    4.970616
# 132    4.102923
# Name: pIC50, Length: 133, dtype: float64

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0             1           1           0  ...             0             0  5.142668
# 1             1           1           0  ...             0             0  5.026872
# 2             1           1           0  ...             0             0  4.869666
# 3             1           1           0  ...             0             0  4.882397
# 4             1           1           0  ...             0             0  5.698970
# ..          ...         ...         ...  ...           ...           ...       ...
# 128           1           1           1  ...             0             0  4.974694
# 129           1           1           1  ...             0             0  4.995679
# 130           1           1           0  ...             0             0  4.939302
# 131           1           1           0  ...             0             0  4.970616
# ...

# %%
dataset3.to_csv('SARS-CoV_bioactivity_data_3class_pIC50_pubchem_fp_04082021.csv', index=False)

# %% [markdown]
# # **Download the CSV file to computer for Model Building.**
